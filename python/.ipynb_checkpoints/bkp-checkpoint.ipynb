# %% [markdown]
# # Data Challenge - loadsmart
# ## By: Cesar Santos

# %% [markdown]
# Development Steps:
# * Importing Data from Excel
# * Threathing Data with Python(Pandas and Numpy)
# * Defining a data model
# * Inserting treated Data into a DW (MySQL Service from Google Clound)
# * Creating a Data Visualization Portifolio Consuming data from the DW

# %% [markdown]
# ### The diagram below shows my basic idea for the data modeling

# %% [markdown]
# ![MER Diagram](..\documentation\loadsmart_diagram-MER.png)

# %% [markdown]
# ## Required Libs:
# pandas=1.2.3
#
# openpyxl==3.0.7
#
# pymysql==0.7.2
#
# numpy==1.20.1
#
# sqlalchemy==1.4.3

# %% [markdown]
# ## Imports

# %%
# Imports
from datetime import datetime
import pandas as pd
import numpy as np
import pymysql.cursors

# %% [markdown]
# ## Data Extraction

# %%
#Data Extraction
source_df = pd.read_excel(r'..\2017 Data- Challenge BI.xlsx', sheet_name='2017 Data',header=0, engine='openpyxl')

#Removing specfic duplicated column
source_df.drop(columns=['has_mobile_app_tracking.1'], inplace=True) 

source_df
# Out:
#        loadsmart_id                                     lane  \
# 0         206431033       Hood River,OR -> Upper Marlboro,MD
# 1         206521177                     Etowah,TN -> Reno,NV
# 2         206694049          Salinas,CA -> Upper Marlboro,MD
# 3         206553113                 Montpelier,OH -> Reno,NV
# 4         206518817                 Newark,DE -> Portland,OR
# ...             ...                                      ...
# 11678     206424529  Colonial Heights,VA -> Daytona Beach,FL
# 11679     206469601                Newark,NJ -> Johnstown,PA
# 11680     206428065     Colonial Heights,VA -> Nottingham,MD
# 11681     206434177           Baldwinsville,NY -> Milford,MA
# 11682     206426689        Fort Collins,CO -> Great Falls,MT
#
#                quote_date           book_date         source_date  \
# 0     2017-12-15 13:08:00 2017-12-15 13:09:00 2017-12-15 13:44:00
# 1     2017-11-20 09:32:00 2017-11-20 09:32:00 2017-11-21 09:46:00
# 2     2017-06-01 18:04:00 2017-06-01 18:04:00 2017-06-02 15:11:00
# 3     2017-11-20 09:10:00 2017-11-20 09:10:00 2017-11-20 12:39:00
# 4     2017-09-25 15:07:00 2017-09-25 15:07:00 2017-09-26 09:05:00
# ...                   ...                 ...                 ...
# 11678 2017-03-24 16:37:00 2017-03-24 16:38:00                 NaT
# 11679 2017-09-11 16:32:00 2017-09-11 16:32:00                 NaT
# 11680 2017-04-21 16:21:00 2017-04-21 16:21:00                 NaT
# 11681 2017-08-01 16:17:00 2017-08-01 16:17:00                 NaT
# 11682 2017-06-26 17:00:00 2017-06-26 17:01:00                 NaT
#
#               pickup_date       delivery_date  book_price  source_price  \
# 0     2017-12-15 11:00:00 2017-12-21 02:00:00     8922.51        8500.0
# 1     2017-11-21 14:00:00 2017-11-27 16:00:00     8726.17        4000.0
# 2     2017-06-03 02:00:00 2017-06-09 04:10:00     8548.19        8220.0
# 3     2017-11-22 17:00:00 2017-11-28 19:00:00     8409.27        5000.0
# 4     2017-09-26 17:00:00 2017-10-02 11:55:00     8351.95        5500.0
# ...                   ...                 ...         ...           ...
# 11678 2017-03-29 09:00:00 2017-03-28 09:14:00        0.00           0.0
# 11679 2017-09-12 23:00:00 2017-09-11 16:33:00        0.00           0.0
# 11680 2017-04-25 02:00:00 2017-04-24 09:49:00        0.00           0.0
# 11681 2017-08-02 11:00:00 2017-08-02 12:10:00        0.00           0.0
# 11682 2017-06-28 18:00:00 2017-06-28 18:26:00        0.00           0.0
#
#            pnl  ...  carrier_on_time_overall pickup_appointment_time  \
# 0       422.51  ...                      1.0     2017-12-15 20:00:00
# 1      4726.17  ...                      1.0     2017-11-21 14:00:00
# 2       328.19  ...                      1.0     2017-06-03 02:00:00
# 3      3409.27  ...                      1.0     2017-11-22 17:00:00
# 4      2851.95  ...                      1.0     2017-09-26 17:00:00
# ...        ...  ...                      ...                     ...
# 11678     0.00  ...                      NaN     2017-03-29 17:00:00
# 11679     0.00  ...                      NaN     2017-09-13 01:00:00
# 11680     0.00  ...                      NaN     2017-04-25 02:00:00
# 11681     0.00  ...                      NaN     2017-08-02 15:00:00
# 11682     0.00  ...                      NaN     2017-06-28 18:00:00
#
#        delivery_appointment_time has_mobile_app_tracking  \
# 0            2017-12-21 00:00:00                   False
# 1            2017-11-27 17:00:00                   False
# 2            2017-06-08 23:00:00                   False
# 3            2017-11-28 19:00:00                   False
# 4            2017-10-02 10:00:00                   False
# ...                          ...                     ...
# 11678        2017-03-30 14:00:00                   False
# 11679        2017-09-13 13:00:00                   False
# 11680        2017-04-25 13:30:00                   False
# 11681        2017-08-02 11:00:00                   False
# 11682        2017-06-30 14:00:00                   False
#
#        has_macropoint_tracking  has_edi_tracking contracted_load  \
# 0                        False             False           False
# 1                        False             False           False
# 2                        False             False           False
# 3                        False             False           False
# 4                        False             False           False
# ...                        ...               ...             ...
# 11678                    False             False           False
# 11679                    False             False           False
# 11680                    False             False           False
# 11681                    False             False           False
# 11682                    False             False           False
#
#       load_booked_autonomously  load_sourced_autonomously  load_was_cancelled
# 0                        False                      False               False
# 1                        False                      False               False
# 2                        False                      False               False
# 3                        False                      False               False
# 4                        False                      False               False
# ...                        ...                        ...                 ...
# 11678                    False                      False                True
# 11679                    False                      False                True
# 11680                    False                      False                True
# 11681                    False                      False                True
# 11682                    False                      False                True
#
# [11683 rows x 30 columns]

# %% [markdown]
# ## Database Connection

# %%
#mysql -uroot -p -h 34.72.119.59 --ssl-ca=server-ca.pem --ssl-cert=client-cert.pem --ssl-key=client-key.pem
connection = pymysql.connect(user = 'loadsmart_user', 
                       password = 'loadsmart_user',
                       database = 'loadsmart_dw', 
                       host = '34.72.119.59', 
                       ssl={
                           'ca': 'server-ca.pem',
                           'key':'client-key.pem',
                           'cert':'client-cert.pem',
                           'check_hostname':False,
                       })

# %% [markdown]
# ## Dim Shipper

# %%
#Dimension Shipper
DimShipper_df = source_df[['shipper_name']].drop_duplicates()

DimShipper_df.head()
# Out:
#     shipper_name
# 0    Shipper 758
# 1   Shipper 1644
# 10   Shipper 585
# 17  Shipper 1249
# 18  Shipper 1375

# %%
# creating column list for insertion
datacolumns = ", ".join([str('`'+i+'`') for i in DimShipper_df.columns.tolist()])

for i,row in DimShipper_df.iterrows():
    try:
        sql = "INSERT INTO `DimShipper` (" +datacolumns + ", `last_update`) VALUES (" + "%s,"*len(row) + "'"+ str(datetime.today())[:19]+ "')"

        connection.cursor().execute(sql, tuple(row))
        connection.commit()
    except:
        connection.commit()
        print('Not Inserted:')
        print(tuple(row))

# %%
#Releasing memory
del DimShipper_df

# %% [markdown]
# ## Dim Route

# %%
#Dimension Route
DimRoute_df = source_df[['lane']].drop_duplicates()

DimRoute_df = DimRoute_df.join(DimRoute_df['lane'].str.split(' -> ', 1,expand=True).rename(columns={0:'source', 1:'destination'}))

DimRoute_df = DimRoute_df.where(pd.notnull(DimRoute_df), None)

DimRoute_df.head()
# Out:
#                                  lane         source        destination
# 0  Hood River,OR -> Upper Marlboro,MD  Hood River,OR  Upper Marlboro,MD
# 1                Etowah,TN -> Reno,NV      Etowah,TN            Reno,NV
# 2     Salinas,CA -> Upper Marlboro,MD     Salinas,CA  Upper Marlboro,MD
# 3            Montpelier,OH -> Reno,NV  Montpelier,OH            Reno,NV
# 4            Newark,DE -> Portland,OR      Newark,DE        Portland,OR

# %%
# creating column list for insertion
datacolumns = ", ".join([str('`'+i+'`') for i in DimRoute_df.columns.tolist()])

for i,row in DimRoute_df.iterrows():
    try:
        sql = "INSERT INTO `DimRoute` (" +datacolumns + ", `last_update`) VALUES (" + "%s,"*len(row) + "'"+ str(datetime.today())[:19]+ "')"

        connection.cursor().execute(sql, tuple(row))
        connection.commit()
    except:
        connection.commit()
        print('Not Inserted:')
        print(tuple(row))

# %%
#Releasing memory
del DimRoute_df

# %% [markdown]
# ## Dim Carrier

# %%
#Dimension Carrier
DimCarrier_df = source_df[['carrier_name','carrier_rating','vip_carrier','carrier_dropped_us_count',
                           'has_mobile_app_tracking','has_macropoint_tracking','has_edi_tracking']].drop_duplicates()

# I didn't understood the column below, so i removed from my data modeling. With more specifc details I'd include this column inside fact table or dimesion.
DimCarrier_df.drop(columns=['carrier_dropped_us_count'], inplace=True)

# Removing duplicated recors after removing carrier_dropped_us_count
DimCarrier_df = DimCarrier_df.drop_duplicates()

DimCarrier_df.rename(columns={'vip_carrier':'fl_vip_carrier',
                              'has_mobile_app_tracking':'fl_has_mobile_app_tracking',
                              'has_macropoint_tracking':'fl_has_macropoint_tracking',
                              'has_edi_tracking':'fl_has_edi_tracking'
                             }, inplace=True)

DimCarrier_df = DimCarrier_df.where(pd.notnull(DimCarrier_df), None)

#Removing carrier nulls, will be replace by -1 in the fact table
DimCarrier_df = DimCarrier_df.loc[DimCarrier_df['carrier_name']!= None]

DimCarrier_df[[DimCarrier_df['carrier_name']== None]]
# Out:
#           carrier_name carrier_rating  fl_vip_carrier  \
# 0       Carrier 605817           None           False
# 1      Carrier 1396487           None           False
# 2      Carrier 1044585           None           False
# 3          Carrier 738           None           False
# 4        Carrier 14533           None           False
# ...                ...            ...             ...
# 10866   Carrier 754417            4.0           False
# 11114  Carrier 1043457           None           False
# 11215   Carrier 733897           None           False
# 11221   Carrier 736749           None           False
# 11563     Carrier 8420           None           False
#
#        fl_has_mobile_app_tracking  fl_has_macropoint_tracking  \
# 0                           False                       False
# 1                           False                       False
# 2                           False                       False
# 3                           False                       False
# 4                           False                       False
# ...                           ...                         ...
# 10866                       False                       False
# 11114                       False                       False
# 11215                       False                       False
# 11221                       False                       False
# 11563                       False                       False
#
#        fl_has_edi_tracking
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 10866                False
# 11114                False
# 11215                False
# 11221                False
# 11563                False
#
# [2752 rows x 6 columns]

# %%
# creating column list for insertion
datacolumns = ", ".join([str('`'+i+'`') for i in DimCarrier_df.columns.tolist()])

for i,row in DimCarrier_df.iterrows():
    try:
        sql = "INSERT INTO `DimCarrier` (" +datacolumns + ", `last_update`) VALUES (" + "%s,"*len(row) + "'"+ str(datetime.today())[:19]+ "')"

        connection.cursor().execute(sql, tuple(row))
        connection.commit()
    except:
        connection.commit()
        print('Not Inserted:')
        print(tuple(row))
# Out:
# (None, None, False, False, False, False)
# (None, None, False, False, False, False)
# (None, None, False, False, False, False)

# %%
#Releasing memory
del DimCarrier_df

# %% [markdown]
# ## Dim Load

# %%
#Dimension Load
DimLoad_df = source_df[['loadsmart_id','equipment_type','sourcing_channel','contracted_load',
                        'load_booked_autonomously','load_sourced_autonomously','load_was_cancelled']].drop_duplicates()

DimLoad_df.rename(columns={'contracted_load':'fl_contracted_load',
                            'load_booked_autonomously':'fl_load_booked_autonomously',
                            'load_sourced_autonomously':'fl_load_sourced_autonomously',
                            'load_was_cancelled':'fl_load_was_cancelled'
                             }, inplace=True)

DimLoad_df = DimLoad_df.where(pd.notnull(DimLoad_df), None)

DimLoad_df.head()
# Out:
#    loadsmart_id equipment_type sourcing_channel  fl_contracted_load  \
# 0     206431033            RFR           dat_in               False
# 1     206521177            DRV             None               False
# 2     206694049            RFR             None               False
# 3     206553113            DRV             None               False
# 4     206518817            DRV             None               False
#
#    fl_load_booked_autonomously  fl_load_sourced_autonomously  \
# 0                        False                         False
# 1                        False                         False
# 2                        False                         False
# 3                        False                         False
# 4                        False                         False
#
#    fl_load_was_cancelled
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False

# %%
# creating column list for insertion
datacolumns = ", ".join([str('`'+i+'`') for i in DimLoad_df.columns.tolist()])

for i,row in DimLoad_df.iterrows():
    try:
        sql = "INSERT INTO `DimLoad` (" +datacolumns + ", `last_update`) VALUES (" + "%s,"*len(row) + "'"+ str(datetime.today())[:19]+ "')"
            
        connection.cursor().execute(sql, tuple(row))
        connection.commit()
    except:
        connection.commit()
        print('Not Inserted:')
        print(tuple(row))

# %%
#Releasing memory
del DimLoad_df

# %% [markdown]
# ## Load Dimensions On Memory

# %%
DimShipper = pd.read_sql_query(
'''select max(sk_code) as sk_code, shipper_name from DimShipper group by shipper_name''', connection)

connection.commit()

DimShipper.head()
# Out:
#    sk_code  shipper_name
# 0       -1       unknown
# 1        1   Shipper 758
# 2        2  Shipper 1644
# 3        3   Shipper 585
# 4        4  Shipper 1249

# %%
DimRoute = pd.read_sql_query(
'''select max(sk_code) as sk_code, lane from DimRoute group by lane''', connection)

connection.commit()

DimShipper.head()
# Out:
#    sk_code  shipper_name
# 0       -1       unknown
# 1        1   Shipper 758
# 2        2  Shipper 1644
# 3        3   Shipper 585
# 4        4  Shipper 1249

# %%
DimCarrier = pd.read_sql_query(
'''select max(sk_code) as sk_code, carrier_name from DimCarrier group by carrier_name''', connection)

connection.commit()

DimCarrier.head()
# Out:
#    sk_code     carrier_name
# 0        1   Carrier 605817
# 1      443  Carrier 1396487
# 2        3  Carrier 1044585
# 3        4      Carrier 738
# 4     1013    Carrier 14533

# %%
DimLoad = pd.read_sql_query(
'''select max(sk_code) as sk_code, loadsmart_id from DimLoad group by loadsmart_id''', connection)

connection.commit()

DimLoad.head()
# Out:
#    sk_code  loadsmart_id
# 0       -1            -1
# 1        1     206431033
# 2        2     206521177
# 3        3     206694049
# 4        4     206553113

# %% [markdown]
# ## FactSales

# %%
FactSales = source_df[['loadsmart_id','carrier_name','lane','shipper_name','quote_date',
                       'book_date','source_date','book_price','source_price','pnl']]

FactSales = FactSales.rename(columns={'quote_date':'quote_datetime',
                         'book_date':'book_datetime',
                         'source_date':'source_datetime',
                         'pnl':'pnl_value'
                        })

FactSales['minutes_between_quote_book'] = FactSales['book_datetime'] - FactSales['quote_datetime'] 
FactSales['minutes_between_quote_book'] = FactSales['minutes_between_quote_book']/np.timedelta64(1,'m')
FactSales['minutes_between_quote_book'] = FactSales['minutes_between_quote_book'].astype(int)

FactSales['sk_load_code'] = FactSales['loadsmart_id'].map(DimLoad.set_index('loadsmart_id')['sk_code'])
FactSales['sk_load_code'] = FactSales['sk_load_code'].where(pd.notnull(FactSales['sk_load_code']), -1)

FactSales['sk_carrier_code'] = FactSales['carrier_name'].map(DimCarrier.set_index('carrier_name')['sk_code'])
FactSales['sk_carrier_code'] = FactSales['sk_carrier_code'].where(pd.notnull(FactSales['sk_carrier_code']), -1)

FactSales['sk_route_code'] = FactSales['lane'].map(DimRoute.set_index('lane')['sk_code'])
FactSales['sk_route_code'] = FactSales['sk_route_code'].where(pd.notnull(FactSales['sk_route_code']), -1)

FactSales['sk_shipper_code'] = FactSales['shipper_name'].map(DimShipper.set_index('shipper_name')['sk_code'])
FactSales['sk_shipper_code'] = FactSales['sk_shipper_code'].where(pd.notnull(FactSales['sk_shipper_code']), -1)
                                                                                         

FactSales = FactSales.where(pd.notnull(FactSales), None)

#REPLACING EMPTY COLUMNS TO AVOID ERRORS
FactSales['source_datetime'] = FactSales['source_datetime'].astype(object).where(FactSales['source_datetime'].notnull(), None)

FactSales = FactSales.drop(columns=['loadsmart_id', 'carrier_name', 'lane', 'shipper_name'])
FactSales
# Out:
#            quote_datetime       book_datetime      source_datetime  \
# 0     2017-12-15 13:08:00 2017-12-15 13:09:00  2017-12-15 13:44:00
# 1     2017-11-20 09:32:00 2017-11-20 09:32:00  2017-11-21 09:46:00
# 2     2017-06-01 18:04:00 2017-06-01 18:04:00  2017-06-02 15:11:00
# 3     2017-11-20 09:10:00 2017-11-20 09:10:00  2017-11-20 12:39:00
# 4     2017-09-25 15:07:00 2017-09-25 15:07:00  2017-09-26 09:05:00
# ...                   ...                 ...                  ...
# 11678 2017-03-24 16:37:00 2017-03-24 16:38:00                 None
# 11679 2017-09-11 16:32:00 2017-09-11 16:32:00                 None
# 11680 2017-04-21 16:21:00 2017-04-21 16:21:00                 None
# 11681 2017-08-01 16:17:00 2017-08-01 16:17:00                 None
# 11682 2017-06-26 17:00:00 2017-06-26 17:01:00                 None
#
#        book_price  source_price  pnl_value  minutes_between_quote_book  \
# 0         8922.51        8500.0     422.51                           1
# 1         8726.17        4000.0    4726.17                           0
# 2         8548.19        8220.0     328.19                           0
# 3         8409.27        5000.0    3409.27                           0
# 4         8351.95        5500.0    2851.95                           0
# ...           ...           ...        ...                         ...
# 11678        0.00           0.0       0.00                           1
# 11679        0.00           0.0       0.00                           0
# 11680        0.00           0.0       0.00                           0
# 11681        0.00           0.0       0.00                           0
# 11682        0.00           0.0       0.00                           1
#
#        sk_load_code  sk_carrier_code  sk_route_code  sk_shipper_code
# 0                 1              1.0              1                1
# 1                 2            443.0              2                2
# 2                 3              3.0              3                1
# 3                 4              4.0              4                2
# 4                 5           1013.0              5                2
# ...             ...              ...            ...              ...
# 11678          5117             -1.0           1541                9
# 11679          5119             -1.0            648                9
# 11680          5120             -1.0           1528                9
# 11681          5121             -1.0            468                9
# 11682          5122             -1.0            287                9
#
# [11683 rows x 11 columns]

# %%
# creating column list for insertion
datacolumns = ", ".join([str('`'+i+'`') for i in FactSales.columns.tolist()])

for i,row in FactSales.iterrows():
    try:
        sql = "INSERT INTO `FactSales` (" +datacolumns + ", `last_update`) VALUES (" + "%s,"*len(row) + "'"+ str(datetime.today())[:19]+ "')"
            
        connection.cursor().execute(sql, tuple(row))
        connection.commit()
    except:
        connection.commit()
        print('Not Inserted:')
        print(tuple(row
12:52:00'), None, 0.0, 0.0, 0.0, 0, 4900, -1.0, 875, 4)
# Not Inserted:
# (Timestamp('2017-05-15 13:34:00'), Timestamp('2017-05-15 13:35:00'), None, 0.0, 0.0, 0.0, 1, 4901, -1.0, 970, 4)
# Not Inserted:
# (Timestamp('2017-12-18 17:40:00'), Timestamp('2017-12-18 17:41:00'), None, 0.0, 0.0, 0.0, 1, 4902, -1.0, 1209, 4)
# Not Inserted:
# (Timestamp('2017-12-06 18:03:00'), Timestamp('2017-12-06 18:03:00'), None, 0.0, 0.0, 0.0, 0, 4903, -1.0, 1486, 2)
# Not Inserted:
# (Timestamp('2017-12-19 08:39:00'), Timestamp('2017-12-19 08:39:00'), None, 0.0, 0.0, 0.0, 0, 4904, -1.0, 9, 2)
# Not Inserted:
# (Timestamp('2017-12-08 08:39:00'), Timestamp('2017-12-08 08:39:00'), None, 0.0, 0.0, 0.0, 0, 4905, -1.0, 1487, 2)
# Not Inserted:
# (Timestamp('2017-10-09 11:48:00'), Timestamp('2017-10-09 11:48:00'), None, 0.0, 0.0, 0.0, 0, 4906, -1.0, 1488, 2)
# Not Inserted:
# (Timestamp('2017-12-19 08:46:00'), Timestamp('2017-12-19 08:46:00'), None, 0.0, 0.0, 0.0, 0, 4907, -1.0, 9, 2)
# Not Inserted:
# (Timestamp('2017-11-17 11:51:00'), Timestamp('2017-11-17 11:51:00'), None, 0.0, 0.0, 0.0, 0, 4908, -1.0, 1121, 2)
# Not Inserted:
# (Timestamp('2017-12-08 08:35:00'), Timestamp('2017-12-08 08:35:00'), None, 0.0, 0.0, 0.0, 0, 4909, -1.0, 1489, 2)
# Not Inserted:
# (Timestamp('2017-10-27 12:46:00'), Timestamp('2017-10-27 12:46:00'), None, 0.0, 150.0, 0.0, 0, 4910, -1.0, 267, 2)
# Not Inserted:
# (Timestamp('2017-10-23 09:28:00'), Timestamp('2017-10-23 09:28:00'), None, 0.0, 0.0, 0.0, 0, 4911, -1.0, 267, 2)
# Not Inserted:
# (Timestamp('2017-10-09 11:53:00'), Timestamp('2017-10-09 11:53:00'), None, 0.0, 0.0, 0.0, 0, 4914, -1.0, 998, 2)
# Not Inserted:
# (Timestamp('2017-10-20 09:00:00'), Timestamp('2017-10-20 09:00:00'), None, 0.0, 0.0, 0.0, 0, 4915, -1.0, 11, 2)
# Not Inserted:
# (Timestamp('2017-11-27 14:30:00'), Timestamp('2017-11-27 14:30:00'), None, 0.0, 0.0, 0.0, 0, 4916, -1.0, 14, 2)
# Not Inserted:
# (Timestamp('2017-12-05 11:54:00'), Timestamp('2017-12-05 11:54:00'), None, 0.0, 0.0, 0.0, 0, 4917, -1.0, 94, 2)
# Not Inserted:
# (Timestamp('2017-11-21 16:40:00'), Timestamp('2017-11-21 16:40:00'), None, 0.0, 0.0, 0.0, 0, 4918, -1.0, 136, 2)
# Not Inserted:
# (Timestamp('2017-11-16 12:38:00'), Timestamp('2017-11-16 12:38:00'), None, 0.0, 0.0, 0.0, 0, 4919, -1.0, 126, 2)
# Not Inserted:
# (Timestamp('2017-12-12 17:19:00'), Timestamp('2017-12-12 17:19:00'), None, 0.0, 0.0, 0.0, 0, 4920, -1.0, 38, 2)
# Not Inserted:
# (Timestamp('2017-12-13 18:25:00'), Timestamp('2017-12-13 18:25:00'), None, 0.0, 0.0, 0.0, 0, 4921, -1.0, 524, 2)
# Not Inserted:
# (Timestamp('2017-10-30 09:33:00'), Timestamp('2017-10-30 09:33:00'), None, 0.0, 0.0, 0.0, 0, 4922, -1.0, 78, 2)
# Not Inserted:
# (Timestamp('2017-11-10 12:53:00'), Timestamp('2017-11-10 12:53:00'), None, 0.0, 0.0, 0.0, 0, 4923, -1.0, 136, 2)
# Not Inserted:
# (Timestamp('2017-10-20 15:12:00'), Timestamp('2017-10-20 15:12:00'), None, 0.0, 0.0, 0.0, 0, 4924, -1.0, 1148, 2)
# Not Inserted:
# (Timestamp('2017-12-06 09:36:00'), Timestamp('2017-12-06 09:36:00'), None, 0.0, 0.0, 0.0, 0, 4925, -1.0, 264, 2)
# Not Inserted:
# (Timestamp('2017-12-08 08:29:00'), Timestamp('2017-12-08 08:29:00'), None, 0.0, 0.0, 0.0, 0, 4926, -1.0, 44, 2)
# Not Inserted:
# (Timestamp('2017-10-26 19:25:00'), Timestamp('2017-10-26 19:25:00'), None, 0.0, 0.0, 0.0, 0, 4927, -1.0, 179, 2)
# Not Inserted:
# (Timestamp('2017-09-27 08:32:00'), Timestamp('2017-09-27 08:32:00'), None, 0.0, 0.0, 0.0, 0, 4928, -1.0, 1492, 2)
# Not Inserted:
# (Timestamp('2017-11-20 08:25:00'), Timestamp('2017-11-20 08:25:00'), None, 0.0, 0.0, 0.0, 0, 4929, -1.0, 65, 2)
# Not Inserted:
# (Timestamp('2017-10-20 17:17:00'), Timestamp('2017-10-20 17:17:00'), None, 0.0, 0.0, 0.0, 0, 4930, -1.0, 263, 2)
# Not Inserted:
# (Timestamp('2017-11-02 09:27:00'), Timestamp('2017-11-02 09:27:00'), None, 0.0, 0.0, 0.0, 0, 4931, -1.0, 44, 2)
# Not Inserted:
# (Timestamp('2017-12-26 15:33:00'), Timestamp('2017-12-26 15:33:00'), None, 0.0, 0.0, 0.0, 0, 4932, -1.0, 44, 2)
# Not Inserted:
# (Timestamp('2017-11-27 16:10:00'), Timestamp('2017-11-27 16:10:00'), None, 0.0, 0.0, 0.0, 0, 4933, -1.0, 50, 2)
# Not Inserted:
# (Timestamp('2017-10-27 12:42:00'), Timestamp('2017-10-27 12:42:00'), None, 0.0, 0.0, 0.0, 0, 4934, -1.0, 267, 2)
# Not Inserted:
# (Timestamp('2017-12-04 09:19:00'), Timestamp('2017-12-04 09:19:00'), None, 0.0, 0.0, 0.0, 0, 4935, -1.0, 272, 2)
# Not Inserted:
# (Timestamp('2017-12-29 11:02:00'), Timestamp('2017-12-29 11:02:00'), None, 0.0, 0.0, 0.0, 0, 4936, -1.0, 7, 2)
# Not Inserted:
# (Timestamp('2017-09-25 16:24:00'), Timestamp('2017-09-25 16:24:00'), None, 0.0, 0.0, 0.0, 0, 4937, -1.0, 287, 4)
# Not Inserted:
# (Timestamp('2017-06-06 16:50:00'), Timestamp('2017-06-06 16:50:00'), None, 0.0, 0.0, 0.0, 0, 4938, -1.0, 724, 4)
# Not Inserted:
# (Timestamp('2017-06-06 17:26:00'), Timestamp('2017-06-06 17:26:00'), None, 0.0, 0.0, 0.0, 0, 4939, -1.0, 622, 4)
# Not Inserted:
# (Timestamp('2017-07-19 16:27:00'), Timestamp('2017-07-19 16:27:00'), None, 0.0, 0.0, 0.0, 0, 4940, -1.0, 421, 4)
# Not Inserted:
# (Timestamp('2017-09-11 16:40:00'), Timestamp('2017-09-11 16:40:00'), None, 0.0, 0.0, 0.0, 0, 4941, -1.0, 912, 4)
# Not Inserted:
# (Timestamp('2017-09-25 17:00:00'), Timestamp('2017-09-25 17:00:00'), None, 0.0, 0.0, 0.0, 0, 4942, -1.0, 1493, 4)
# Not Inserted:
# (Timestamp('2017-05-10 13:46:00'), Timestamp('2017-05-10 13:46:00'), None, 0.0, 0.0, 0.0, 0, 4943, -1.0, 1180, 4)
# Not Inserted:
# (Timestamp('2017-12-04 09:44:00'), Timestamp('2017-12-04 09:44:00'), None, 0.0, 0.0, 0.0, 0, 4944, -1.0, 1012, 4)
# Not Inserted:
# (Timestamp('2017-09-26 17:00:00'), Timestamp('2017-09-26 17:00:00'), None, 0.0, 0.0, 0.0, 0, 4945, -1.0, 1494, 4)
# Not Inserted:
# (Timestamp('2017-04-03 16:31:00'), Timestamp('2017-04-03 16:31:00'), None, 0.0, 0.0, 0.0, 0, 4946, -1.0, 124, 4)
# Not Inserted:
# (Timestamp('2017-04-17 16:49:00'), Timestamp('2017-04-17 16:49:00'), None, 0.0, 0.0, 0.0, 0, 4947, -1.0, 1251, 4)
# Not Inserted:
# (Timestamp('2017-09-20 17:11:00'), Timestamp('2017-09-20 17:11:00'), None, 0.0, 0.0, 0.0, 0, 4948, -1.0, 1187, 4)
# Not Inserted:
# (Timestamp('2017-05-31 11:54:00'), Timestamp('2017-05-31 11:57:00'), None, 0.0, 0.0, 0.0, 3, 4949, -1.0, 752, 4)
# Not Inserted:
# (Timestamp('2017-09-18 17:56:00'), Timestamp('2017-09-18 17:56:00'), None, 0.0, 0.0, 0.0, 0, 4950, -1.0, 713, 4)
# Not Inserted:
# (Timestamp('2017-05-15 12:58:00'), Timestamp('2017-05-15 12:58:00'), None, 0.0, 0.0, 0.0, 0, 4951, -1.0, 1400, 4)
# Not Inserted:
# (Timestamp('2017-09-11 16:50:00'), Timestamp('2017-09-11 16:50:00'), None, 0.0, 0.0, 0.0, 0, 4952, -1.0, 225, 4)
# Not Inserted:
# (Timestamp('2017-12-29 12:52:00'), Timestamp('2017-12-29 12:52:00'), None, 0.0, 0.0, 0.0, 0, 4953, -1.0, 552, 4)
# Not Inserted:
# (Timestamp('2017-09-26 16:24:00'), Timestamp('2017-09-26 16:24:00'), None, 0.0, 0.0, 0.0, 0, 4954, -1.0, 586, 4)
# Not Inserted:
# (Timestamp('2017-06-06 16:55:00'), Timestamp('2017-06-06 16:56:00'), None, 0.0, 0.0, 0.0, 1, 4955, -1.0, 724, 4)
# Not Inserted:
# (Timestamp('2017-09-14 17:31:00'), Timestamp('2017-09-14 17:31:00'), None, 0.0, 0.0, 0.0, 0, 4956, -1.0, 581, 4)
# Not Inserted:
# (Timestamp('2017-09-15 16:51:00'), Timestamp('2017-09-15 16:51:00'), None, 0.0, 0.0, 0.0, 0, 4957, -1.0, 813, 4)
# Not Inserted:
# (Timestamp('2017-12-04 10:11:00'), Timestamp('2017-12-04 10:12:00'), None, 0.0, 0.0, 0.0, 1, 4958, -1.0, 537, 4)
# Not Inserted:
# (Timestamp('2017-07-31 15:22:00'), Timestamp('2017-07-31 15:22:00'), None, 0.0, 0.0, 0.0, 0, 4959, -1.0, 1495, 4)
# Not Inserted:
# (Timestamp('2017-06-09 16:18:00'), Timestamp('2017-06-09 16:18:00'), None, 0.0, 0.0, 0.0, 0, 4960, -1.0, 1496, 4)
# Not Inserted:
# (Timestamp('2017-12-18 23:39:00'), Timestamp('2017-12-18 23:39:00'), None, 0.0, 0.0, 0.0, 0, 4961, -1.0, 1497, 4)
# Not Inserted:
# (Timestamp('2017-05-02 13:52:00'), Timestamp('2017-05-02 13:52:00'), None, 0.0, 0.0, 0.0, 0, 4962, -1.0, 1441, 4)
# Not Inserted:
# (Timestamp('2017-09-20 17:03:00'), Timestamp('2017-09-20 17:04:00'), None, 0.0, 0.0, 0.0, 1, 4963, -1.0, 1498, 4)
# Not Inserted:
# (Timestamp('2017-12-18 16:29:00'), Timestamp('2017-12-18 16:29:00'), None, 0.0, 0.0, 0.0, 0, 4964, -1.0, 1499, 4)
# Not Inserted:
# (Timestamp('2017-11-16 16:31:00'), Timestamp('2017-11-16 16:31:00'), None, 0.0, 0.0, 0.0, 0, 4965, -1.0, 1500, 4)
# Not Inserted:
# (Timestamp('2017-05-30 11:34:00'), Timestamp('2017-05-30 11:34:00'), None, 0.0, 0.0, 0.0, 0, 4966, -1.0, 1501, 4)
# Not Inserted:
# (Timestamp('2017-12-18 15:21:00'), Timestamp('2017-12-18 15:21:00'), None, 0.0, 0.0, 0.0, 0, 4967, -1.0, 417, 4)
# Not Inserted:
# (Timestamp('2017-03-01 08:29:00'), Timestamp('2017-03-01 08:32:00'), None, 0.0, 0.0, 0.0, 3, 4968, -1.0, 1172, 102)
# Not Inserted:
# (Timestamp('2017-06-05 17:55:00'), Timestamp('2017-06-05 17:55:00'), None, 0.0, 0.0, 0.0, 0, 4969, -1.0, 1433, 103)
# Not Inserted:
# (Timestamp('2017-08-14 15:53:00'), Timestamp('2017-08-14 15:53:00'), None, 0.0, 0.0, 0.0, 0, 4970, -1.0, 1502, 103)
# Not Inserted:
# (Timestamp('2017-06-05 17:54:00'), Timestamp('2017-06-05 17:54:00'), None, 0.0, 0.0, 0.0, 0, 4971, -1.0, 1433, 103)
# Not Inserted:
# (Timestamp('2017-06-05 17:55:00'), Timestamp('2017-06-05 17:55:00'), None, 0.0, 0.0, 0.0, 0, 4972, -1.0, 1433, 103)
# Not Inserted:
# (Timestamp('2017-09-11 16:01:00'), Timestamp('2017-09-11 16:01:00'), None, 0.0, 0.0, 0.0, 0, 4973, -1.0, 1503, 60)
# Not Inserted:
# (Timestamp('2017-06-05 17:55:00'), Timestamp('2017-06-05 17:55:00'), None, 0.0, 0.0, 0.0, 0, 4969, -1.0, 1433, 104)
# Not Inserted:
# (Timestamp('2017-08-14 15:53:00'), Timestamp('2017-08-14 15:53:00'), None, 0.0, 0.0, 0.0, 0, 4970, -1.0, 1502, 104)
# Not Inserted:
# (Timestamp('2017-06-05 17:54:00'), Timestamp('2017-06-05 17:54:00'), None, 0.0, 0.0, 0.0, 0, 4971, -1.0, 1433, 104)
# Not Inserted:
# (Timestamp('2017-06-05 17:55:00'), Timestamp('2017-06-05 17:55:00'), None, 0.0, 0.0, 0.0, 0, 4972, -1.0, 1433, 104)
# Not Inserted:
# (Timestamp('2017-07-24 14:19:00'), Timestamp('2017-07-24 14:19:00'), None, 0.0, 0.0, 0.0, 0, 4974, -1.0, 503, 4)
# Not Inserted:
# (Timestamp('2017-09-18 17:53:00'), Timestamp('2017-09-18 17:53:00'), None, 0.0, 0.0, 0.0, 0, 4975, -1.0, 713, 4)
# Not Inserted:
# (Timestamp('2017-09-07 16:56:00'), Timestamp('2017-09-07 16:56:00'), None, 0.0, 0.0, 0.0, 0, 4977, -1.0, 484, 4)
# Not Inserted:
# (Timestamp('2017-06-23 16:20:00'), Timestamp('2017-06-23 16:21:00'), None, 0.0, 0.0, 0.0, 1, 4978, -1.0, 1015, 4)
# Not Inserted:
# (Timestamp('2017-11-08 08:47:00'), Timestamp('2017-11-08 08:47:00'), None, 0.0, 0.0, 0.0, 0, 4979, -1.0, 1504, 4)
# Not Inserted:
# (Timestamp('2017-06-06 17:00:00'), Timestamp('2017-06-06 17:00:00'), None, 0.0, 0.0, 0.0, 0, 4980, -1.0, 724, 4)
# Not Inserted:
# (Timestamp('2017-09-27 17:08:00'), Timestamp('2017-09-27 17:08:00'), None, 0.0, 0.0, 0.0, 0, 4981, -1.0, 1505, 4)
# Not Inserted:
# (Timestamp('2017-08-23 16:36:00'), Timestamp('2017-08-23 16:36:00'), None, 0.0, 0.0, 0.0, 0, 4983, -1.0, 429, 4)
# Not Inserted:
# (Timestamp('2017-05-12 16:17:00'), Timestamp('2017-05-12 16:17:00'), None, 0.0, 0.0, 0.0, 0, 4984, -1.0, 499, 4)
# Not Inserted:
# (Timestamp('2017-06-26 16:56:00'), Timestamp('2017-06-26 16:57:00'), None, 0.0, 0.0, 0.0, 1, 4985, -1.0, 1506, 4)
# Not Inserted:
# (Timestamp('2017-12-12 17:07:00'), Timestamp('2017-12-12 17:07:00'), None, 0.0, 0.0, 0.0, 0, 4986, -1.0, 1236, 4)
# Not Inserted:
# (Timestamp('2017-06-06 18:10:00'), Timestamp('2017-06-06 18:10:00'), None, 0.0, 0.0, 0.0, 0, 4987, -1.0, 1507, 4)
# Not Inserted:
# (Timestamp('2017-09-18 18:00:00'), Timestamp('2017-09-18 18:00:00'), None, 0.0, 0.0, 0.0, 0, 4988, -1.0, 183, 4)
# Not Inserted:
# (Timestamp('2017-04-28 16:50:00'), Timestamp('2017-04-28 16:50:00'), None, 0.0, 0.0, 0.0, 0, 4989, -1.0, 1508, 4)
# Not Inserted:
# (Timestamp('2017-07-27 16:22:00'), Timestamp('2017-07-27 16:22:00'), None, 0.0, 0.0, 0.0, 0, 4990, -1.0, 1276, 4)
# Not Inserted:
# (Timestamp('2017-12-14 16:38:00'), Timestamp('2017-12-14 16:38:00'), None, 0.0, 0.0, 0.0, 0, 4991, -1.0, 783, 4)
# Not Inserted:
# (Timestamp('2017-10-16 16:14:00'), Timestamp('2017-10-16 16:14:00'), None, 0.0, 0.0, 0.0, 0, 4992, -1.0, 598, 4)
# Not Inserted:
# (Timestamp('2017-08-28 10:02:00'), Timestamp('2017-08-28 10:02:00'), None, 0.0, 0.0, 0.0, 0, 4993, -1.0, 266, 4)
# Not Inserted:
# (Timestamp('2017-04-17 16:54:00'), Timestamp('2017-04-17 16:54:00'), None, 0.0, 0.0, 0.0, 0, 4994, -1.0, 1251, 4)
# Not Inserted:
# (Timestamp('2017-08-01 16:24:00'), Timestamp('2017-08-01 16:24:00'), None, 0.0, 0.0, 0.0, 0, 4995, -1.0, 468, 4)
# Not Inserted:
# (Timestamp('2017-12-18 18:43:00'), Timestamp('2017-12-18 18:43:00'), None, 0.0, 0.0, 0.0, 0, 4996, -1.0, 924, 4)
# Not Inserted:
# (Timestamp('2017-01-09 12:40:00'), Timestamp('2017-01-09 12:42:00'), None, 0.0, 0.0, 0.0, 2, 4997, -1.0, 1509, 76)
# Not Inserted:
# (Timestamp('2017-09-25 13:52:00'), Timestamp('2017-09-25 13:52:00'), None, 0.0, 0.0, 0.0, 0, 4998, -1.0, 1510, 57)
# Not Inserted:
# (Timestamp('2017-06-01 12:15:00'), Timestamp('2017-06-01 12:15:00'), None, 0.0, 0.0, 0.0, 0, 4999, -1.0, 1210, 57)
# Not Inserted:
# (Timestamp('2017-03-28 13:27:00'), Timestamp('2017-03-28 13:29:00'), None, 0.0, 0.0, 0.0, 2, 5000, -1.0, 1511, 57)
# Not Inserted:
# (Timestamp('2017-09-25 13:49:00'), Timestamp('2017-09-25 13:50:00'), None, 0.0, 0.0, 0.0, 1, 5001, -1.0, 1332, 57)
# Not Inserted:
# (Timestamp('2017-06-13 15:05:00'), Timestamp('2017-06-13 15:05:00'), None, 0.0, 0.0, 0.0, 0, 5002, -1.0, 1328, 57)
# Not Inserted:
# (Timestamp('2017-06-12 14:16:00'), Timestamp('2017-06-12 14:16:00'), None, 0.0, 0.0, 0.0, 0, 5003, -1.0, 1328, 57)
# Not Inserted:
# (Timestamp('2017-08-16 10:48:00'), Timestamp('2017-08-16 10:48:00'), None, 0.0, 0.0, 0.0, 0, 5004, -1.0, 1512, 57)
# Not Inserted:
# (Timestamp('2017-06-12 14:14:00'), Timestamp('2017-06-12 14:15:00'), None, 0.0, 0.0, 0.0, 1, 5005, -1.0, 1328, 57)
# Not Inserted:
# (Timestamp('2017-09-06 13:18:00'), Timestamp('2017-09-06 13:18:00'), None, 0.0, 0.0, 0.0, 0, 5006, -1.0, 816, 18)
# Not Inserted:
# (Timestamp('2017-08-28 13:52:00'), Timestamp('2017-08-28 13:52:00'), None, 0.0, 0.0, 0.0, 0, 5007, -1.0, 1513, 18)
# Not Inserted:
# (Timestamp('2017-05-15 10:09:00'), Timestamp('2017-05-15 10:10:00'), None, 0.0, 0.0, 0.0, 1, 5008, -1.0, 1369, 84)
# Not Inserted:
# (Timestamp('2017-05-31 14:23:00'), Timestamp('2017-05-31 14:23:00'), None, 0.0, 0.0, 0.0, 0, 5009, -1.0, 822, 66)
# Not Inserted:
# (Timestamp('2017-07
-1.0, 1371, 54)
# Not Inserted:
# (Timestamp('2017-04-24 09:01:00'), Timestamp('2017-04-24 09:01:00'), None, 0.0, 0.0, 0.0, 0, 5029, -1.0, 655, 35)
# Not Inserted:
# (Timestamp('2017-03-09 14:34:00'), Timestamp('2017-03-09 14:42:00'), None, 0.0, 0.0, 0.0, 8, 5030, -1.0, 1520, 35)
# Not Inserted:
# (Timestamp('2017-05-31 10:11:00'), Timestamp('2017-05-31 10:11:00'), None, 0.0, 0.0, 0.0, 0, 5031, -1.0, 1521, 35)
# Not Inserted:
# (Timestamp('2017-06-20 14:05:00'), Timestamp('2017-06-20 14:05:00'), None, 0.0, 0.0, 0.0, 0, 5032, -1.0, 1522, 35)
# Not Inserted:
# (Timestamp('2017-02-15 14:19:00'), Timestamp('2017-02-15 14:21:00'), None, 0.0, 0.0, 0.0, 2, 5033, -1.0, 1289, 35)
# Not Inserted:
# (Timestamp('2017-05-31 10:17:00'), Timestamp('2017-05-31 10:17:00'), None, 0.0, 0.0, 0.0, 0, 5034, -1.0, 1521, 35)
# Not Inserted:
# (Timestamp('2017-03-24 12:27:00'), Timestamp('2017-03-24 12:27:00'), None, 0.0, 0.0, 0.0, 0, 5035, -1.0, 1289, 35)
# Not Inserted:
# (Timestamp('2017-01-24 09:38:00'), Timestamp('2017-01-24 09:38:00'), None, 0.0, 0.0, 0.0, 0, 5036, -1.0, 1523, 35)
# Not Inserted:
# (Timestamp('2017-01-12 11:09:00'), Timestamp('2017-01-12 11:10:00'), None, 0.0, 0.0, 0.0, 1, 5037, -1.0, 1358, 35)
# Not Inserted:
# (Timestamp('2017-09-15 16:17:00'), Timestamp('2017-09-15 16:17:00'), None, 0.0, 0.0, 0.0, 0, 5038, -1.0, 22, 11)
# Not Inserted:
# (Timestamp('2017-09-15 17:17:00'), Timestamp('2017-09-15 17:17:00'), None, 0.0, 0.0, 0.0, 0, 5039, -1.0, 22, 11)
# Not Inserted:
# (Timestamp('2017-11-03 09:33:00'), Timestamp('2017-11-03 09:33:00'), None, 0.0, 0.0, 0.0, 0, 5040, -1.0, 1524, 2)
# Not Inserted:
# (Timestamp('2017-09-27 08:48:00'), Timestamp('2017-09-27 08:48:00'), None, 0.0, 0.0, 0.0, 0, 5041, -1.0, 1456, 2)
# Not Inserted:
# (Timestamp('2017-12-11 08:48:00'), Timestamp('2017-12-11 08:48:00'), None, 0.0, 0.0, 0.0, 0, 5042, -1.0, 226, 2)
# Not Inserted:
# (Timestamp('2017-10-06 10:08:00'), Timestamp('2017-10-06 10:08:00'), None, 0.0, 0.0, 0.0, 0, 5043, -1.0, 585, 2)
# Not Inserted:
# (Timestamp('2017-11-03 09:28:00'), Timestamp('2017-11-03 09:28:00'), None, 0.0, 0.0, 0.0, 0, 5044, -1.0, 1524, 2)
# Not Inserted:
# (Timestamp('2017-10-20 17:13:00'), Timestamp('2017-10-20 17:13:00'), None, 0.0, 0.0, 0.0, 0, 5045, -1.0, 263, 2)
# Not Inserted:
# (Timestamp('2017-09-15 12:45:00'), Timestamp('2017-09-15 12:46:00'), None, 0.0, 0.0, 0.0, 1, 5046, -1.0, 1525, 2)
# Not Inserted:
# (Timestamp('2017-10-23 06:12:00'), Timestamp('2017-10-23 06:12:00'), None, 0.0, 0.0, 0.0, 0, 5047, -1.0, 267, 2)
# Not Inserted:
# (Timestamp('2017-10-16 10:42:00'), Timestamp('2017-10-16 10:42:00'), None, 0.0, 0.0, 0.0, 0, 5048, -1.0, 116, 2)
# Not Inserted:
# (Timestamp('2017-01-26 13:14:00'), Timestamp('2017-01-26 14:14:00'), None, 0.0, 0.0, 0.0, 60, 5049, -1.0, 1526, 46)
# Not Inserted:
# (Timestamp('2017-02-13 10:07:00'), Timestamp('2017-02-13 10:08:00'), None, 0.0, 0.0, 0.0, 1, 5050, -1.0, 1125, 46)
# Not Inserted:
# (Timestamp('2017-04-03 17:19:00'), Timestamp('2017-04-03 17:20:00'), None, 0.0, 0.0, 0.0, 1, 5051, -1.0, 555, 46)
# Not Inserted:
# (Timestamp('2017-07-12 14:43:00'), Timestamp('2017-07-12 14:43:00'), None, 0.0, 0.0, 0.0, 0, 5052, -1.0, 902, 19)
# Not Inserted:
# (Timestamp('2017-12-14 16:55:00'), Timestamp('2017-12-14 16:55:00'), None, 0.0, 0.0, 0.0, 0, 5053, -1.0, 566, 4)
# Not Inserted:
# (Timestamp('2017-05-16 17:29:00'), Timestamp('2017-05-16 17:29:00'), None, 0.0, 0.0, 0.0, 0, 5054, -1.0, 512, 4)
# Not Inserted:
# (Timestamp('2017-08-23 16:16:00'), Timestamp('2017-08-23 16:16:00'), None, 0.0, 0.0, 0.0, 0, 5055, -1.0, 682, 4)
# Not Inserted:
# (Timestamp('2017-12-14 16:45:00'), Timestamp('2017-12-14 16:46:00'), None, 0.0, 0.0, 0.0, 1, 5056, -1.0, 946, 4)
# Not Inserted:
# (Timestamp('2017-07-24 17:07:00'), Timestamp('2017-07-24 17:07:00'), None, 0.0, 0.0, 0.0, 0, 5057, -1.0, 1527, 4)
# Not Inserted:
# (Timestamp('2017-05-31 14:00:00'), Timestamp('2017-05-31 14:01:00'), None, 0.0, 0.0, 0.0, 1, 5058, -1.0, 1008, 4)
# Not Inserted:
# (Timestamp('2017-09-07 10:44:00'), Timestamp('2017-09-07 10:45:00'), None, 0.0, 0.0, 0.0, 1, 5059, -1.0, 681, 4)
# Not Inserted:
# (Timestamp('2017-04-19 16:27:00'), Timestamp('2017-04-19 16:28:00'), None, 0.0, 0.0, 0.0, 1, 5060, -1.0, 254, 4)
# Not Inserted:
# (Timestamp('2017-12-04 16:55:00'), Timestamp('2017-12-04 16:55:00'), None, 0.0, 0.0, 0.0, 0, 5061, -1.0, 16, 4)
# Not Inserted:
# (Timestamp('2017-10-20 17:21:00'), Timestamp('2017-10-20 17:21:00'), None, 0.0, 0.0, 0.0, 0, 5062, -1.0, 587, 4)
# Not Inserted:
# (Timestamp('2017-06-09 16:43:00'), Timestamp('2017-06-09 16:43:00'), None, 0.0, 0.0, 0.0, 0, 5063, -1.0, 390, 4)
# Not Inserted:
# (Timestamp('2017-03-27 16:55:00'), Timestamp('2017-03-27 16:55:00'), None, 0.0, 0.0, 0.0, 0, 5064, -1.0, 1528, 4)
# Not Inserted:
# (Timestamp('2017-09-18 17:12:00'), Timestamp('2017-09-18 17:12:00'), None, 0.0, 0.0, 0.0, 0, 5065, -1.0, 435, 4)
# Not Inserted:
# (Timestamp('2017-06-09 16:47:00'), Timestamp('2017-06-09 16:47:00'), None, 0.0, 0.0, 0.0, 0, 5066, -1.0, 566, 4)
# Not Inserted:
# (Timestamp('2017-09-15 16:39:00'), Timestamp('2017-09-15 16:39:00'), None, 0.0, 0.0, 0.0, 0, 5067, -1.0, 728, 4)
# Not Inserted:
# (Timestamp('2017-11-09 17:18:00'), Timestamp('2017-11-09 17:18:00'), None, 0.0, 0.0, 0.0, 0, 5068, -1.0, 539, 4)
# Not Inserted:
# (Timestamp('2017-06-06 16:58:00'), Timestamp('2017-06-06 16:58:00'), None, 0.0, 0.0, 0.0, 0, 5069, -1.0, 724, 4)
# Not Inserted:
# (Timestamp('2017-04-10 16:56:00'), Timestamp('2017-04-10 16:56:00'), None, 0.0, 0.0, 0.0, 0, 
-1.0, 1251, 4)
# Not Inserted:
# (Timestamp('2017-05-10 13:16:00'), Timestamp('2017-05-10 13:17:00'), None, 0.0, 0.0, 0.0, 1, 5094, -1.0, 507, 4)
# Not Inserted:
# (Timestamp('2017-12-04 10:16:00'), Timestamp('2017-12-04 10:16:00'), None, 0.0, 0.0, 0.0, 0, 5095, -1.0, 513, 4)
# Not Inserted:
# (Timestamp('2017-05-02 13:46:00'), Timestamp('2017-05-02 13:46:00'), None, 0.0, 0.0, 0.0, 0, 5096, -1.0, 1441, 4)
# Not Inserted:
# (Timestamp('2017-06-27 17:16:00'), Timestamp('2017-06-27 17:17:00'), None, 0.0, 0.0, 0.0, 1, 5098, -1.0, 269, 4)
# Not Inserted:
# (Timestamp('2017-04-10 16:59:00'), Timestamp('2017-04-10 17:00:00'), None, 0.0, 0.0, 0.0, 1, 5099, -1.0, 1484, 4)
# Not Inserted:
# (Timestamp('2017-12-19 09:26:00'), Timestamp('2017-12-19 09:26:00'), None, 0.0, 0.0, 0.0, 0, 5100, -1.0, 776, 4)
# Not Inserted:
# (Timestamp('2017-06-06 16:48:00'), Timestamp('2017-06-06 16:48:00'), None, 0.0, 0.0, 0.0, 0, 5101, -1.0, 724, 4)
# Not Inserted:
# (Timestamp('2017-04-10 17:20:00'), Timestamp('2017-04-10 17:20:00'), None, 0.0, 0.0, 0.0, 0, 5102, -1.0, 1533, 4)
# Not Inserted:
# (Timestamp('2017-05-24 17:37:00'), Timestamp('2017-05-24 17:37:00'), None, 0.0, 0.0, 0.0, 0, 5103, -1.0, 512, 4)
# Not Inserted:
# (Timestamp('2017-09-27 17:05:00'), Timestamp('2017-09-27 17:05:00'), None, 0.0, 0.0, 0.0, 0, 5104, -1.0, 1534, 4)
# Not Inserted:
# (Timestamp('2017-09-20 17:19:00'), Timestamp('2017-09-20 17:19:00'), None, 0.0, 0.0, 0.0, 0, 5105, -1.0, 1535, 4)
# Not Inserted:
# (Timestamp('2017-08-31 13:00:00'), Timestamp('2017-08-31 13:00:00'), None, 0.0, 0.0, 0.0, 0, 5106, -1.0, 442, 4)
# Not Inserted:
# (Timestamp('2017-04-28 15:25:00'), Timestamp('2017-04-28 15:26:00'), None, 0.0, 0.0, 0.0, 1, 5107, -1.0, 1536, 4)
# Not Inserted:
# (Timestamp('2017-04-28 16:54:00'), Timestamp('2017-04-28 16:54:00'), None, 0.0, 0.0, 0.0, 0, 5108, -1.0, 1537, 4)
# Not Inserted:
# (Timestamp('2017-07-31 14:45:00'), Timestamp('2017-07-31 14:45:00'), None, 0.0, 0.0, 0.0, 0, 5109, -1.0, 1538, 4)
# Not Inserted:
# (Timestamp('2017-05-16 14:52:00'), Timestamp('2017-05-16 14:52:00'), None, 0.0, 0.0, 0.0, 0, 5110, -1.0, 512, 4)
# Not Inserted:
# (Timestamp('2017-10-27 16:56:00'), Timestamp('2017-10-27 16:56:00'), None, 0.0, 0.0, 0.0, 0, 5111, -1.0, 1539, 4)
# Not Inserted:
# (Timestamp('2017-06-20 10:15:00'), Timestamp('2017-06-20 10:15:00'), None, 0.0, 0.0, 0.0, 0, 5112, -1.0, 1540, 4)
# Not Inserted:
# (Timestamp('2017-09-07 16:56:00'), Timestamp('2017-09-07 16:56:00'), None, 0.0, 0.0, 0.0, 0, 5113, -1.0, 484, 4)
# Not Inserted:
# (Timestamp('2017-12-04 09:52:00'), Timestamp('2017-12-04 09:52:00'), None, 0.0, 0.0, 0.0, 0, 5114, -1.0, 1480, 4)
# Not Inserted:
# (Timestamp('2017-04-28 17:04:00'), Timestamp('2017-04-28 17:04:00'), None, 0.0, 0.0, 0.0, 0, 5115, -1.0, 1508, 4)
# Not Inserted:
# (Timestamp('2017-08-22 16:29:00'), Timestamp('2017-08-22 16:29:00'), None, 0.0, 0.0, 0.0, 0, 5116, -1.0, 346, 4)
# Not Inserted:
# (Timestamp('2017-03-24 16:37:00'), Timestamp('2017-03-24 16:38:00'), None, 0.0, 0.0, 0.0, 1, 5117, -1.0, 1541, 4)
# Not Inserted:
# (Timestamp('2017-09-11 16:32:00'), Timestamp('2017-09-11 16:32:00'), None, 0.0, 0.0, 0.0, 0, 5119, -1.0, 648, 4)
# Not Inserted:
# (Timestamp('2017-04-21 16:21:00'), Timestamp('2017-04-21 16:21:00'), None, 0.0, 0.0, 0.0, 0, 5120, -1.0, 1528, 4)
# Not Inserted:
# (Timestamp('2017-08-01 16:17:00'), Timestamp('2017-08-01 16:17:00'), None, 0.0, 0.0, 0.0, 0, 5121, -1.0, 468, 4)
# Not Inserted:
# (Timestamp('2017-06-26 17:00:00'), Timestamp('2017-06-26 17:01:00'), None, 0.0, 0.0, 0.0, 1, 5122, -1.0, 287, 4)
# Not Inserted:
# (Timestamp('2017-12-04 17:06:00'), Timestamp('2017-12-04 17:06:00'), None, 0.0, 0.0, 0.0, 0, 4877, -1.0, 12, 5)
# Not Inserted:
# (Timestamp('2017-09-14 17:26:00'), Timestamp('2017-09-14 17:26:00'), None, 0.0, 0.0, 0.0, 0, 4878, -1.0, 1473, 5)
# Not Inserted:
# (Timestamp('2017-06-27 17:24:00'), Timestamp('2017-06-27 17:25:00'), None, 0.0, 0.0, 0.0, 1, 4879, -1.0, 269, 5)
# Not Inserted:
# (Timestamp('2017-12-29 12:52:00'), Timestamp('2017-12-29 12:52:00'), None, 0.0, 0.0, 0.0, 0, 4880, -1.0, 552, 5)
# Not Inserted:
# (Timestamp('2017-06-26 14:39:00'), Timestamp('2017-06-26 14:40:00'), None, 0.0, 0.0, 0.0, 1, 4881, -1.0, 418, 5)
# Not Inserted:
# (Timestamp('2017-06-09 16:34:00'), Timestamp('2017-06-09 16:35:00'), None, 0.0, 0.0, 0.0, 1, 4882, -1.0, 1474, 5)
# Not Inserted:
# (Timestamp('2017-11-01 16:15:00'), Timestamp('2017-11-01 16:15:00'), None, 0.0, 0.0, 0.0, 0, 4883, -1.0, 1475, 5)
# Not Inserted:
# (Timestamp('2017-08-01 11:54:00'), Timestamp('2017-08-01 11:54:00'), None, 0.0, 0.0, 0.0, 0, 4884, -1.0, 1476, 5)
# Not Inserted:
# (Timestamp('2017-12-18 18:19:00'), Timestamp('2017-12-18 18:19:00'), None, 0.0, 0.0, 0.0, 0, 4885, -1.0, 1477, 5)
# Not Inserted:
# (Timestamp('2017-05-22 15:19:00'), Timestamp('2017-05-22 15:19:00'), None, 0.0, 0.0, 0.0, 0, 4886, -1.0, 1284, 5)
# Not Inserted:
# (Timestamp('2017-07-07 16:20:00'), Timestamp('2017-07-07 16:20:00'), None, 0.0, 0.0, 0.0, 0, 4887, -1.0, 512, 5)
# Not Inserted:
# (Timestamp('2017-09-19 09:32:00'), Timestamp('2017-09-19 09:32:00'), None, 0.0, 0.0, 0.0, 0, 4888, -1.0, 1478, 5)
# Not Inserted:
# (Timestamp('2017-07-26 10:59:00'), Timestamp('2017-07-26 10:59:00'), None, 0.0, 0.0, 0.0, 0, 4889, -1.0, 1479, 5)
# Not Inserted:
# (Timestamp('2017-10-20 17:31:00'), Timestamp('2017-10-20 17:31:00'), None, 0.0, 0.0, 0.0, 0, 4890, -1.0, 1480, 5)
# Not Inserted:
# (Timestamp('2017-06-06 16:52:00'), Timestamp('2017-06-06 16:52:00'), None, 0.0, 0.0, 0.0, 0, 4891, -1.0, 724, 5)
# Not Inserted:
# (Timestamp('2017-09-08 19:25:00'), Timestamp('2017-09-08 19:25:00'), None, 0.0, 0.0, 0.0, 0, 4892, -1.0, 1481, 5)
# Not Inserted:
# (Timestamp('2017-09-15 16:54:00'), Timestamp('2017-09-15 16:54:00'), None, 0.0, 0.0, 0.0, 0, 4893, -1.0, 1482, 5)
# Not Inserted:
# (Timestamp('2017-09-27 16:35:00'), Timestamp('2017-09-27 16:35:00'), None, 0.0, 0.0, 0.0, 0, 4894, -1.0, 1483, 5)
# Not Inserted:
# (Timestamp('2017-04-10 17:00:00'), Timestamp('2017-04-10 17:00:00'), None, 0.0, 0.0, 0.0, 0, 4895, -1.0, 1484, 5)
# Not Inserted:
# (Timestamp('2017-03-27 17:53:00'), Timestamp('2017-03-27 17:53:00'), None, 0.0, 0.0, 0.0, 0, 4899, -1.0, 375, 5)
# Not Inserted:
# (Timestamp('2017-05-12 12:52:00'), Timestamp('2017-05-12 12:52:00'), None, 0.0, 0.0, 0.0, 0, 4900, -1.0, 875, 5)
# Not Inserted:
# (Timestamp('2017-05-15 13:34:00'), Timestamp('2017-05-15 13:35:00'), None, 0.0, 0.0, 0.0, 1, 4901, -1.0, 970, 5)
# Not Inserted:
# (Timestamp('2017-12-18 17:40:00'), Timestamp('2017-12-18 17:41:00'), None, 0.0, 0.0, 0.0, 1, 4902, -1.0, 1209, 5)
# Not Inserted:
# (Timestamp('2017-09-25 16:24:00'), Timestamp('2017-09-25 16:24:00'), None, 0.0, 0.0, 0.0, 0, 4937, -1.0, 287, 5)
# Not Inserted:
# (Timestamp('2017-06-06 16:50:00'), Timestamp('2017-06-06 16:50:00'), None, 0.0, 0.0, 0.0, 0, 4938, -1.0, 724, 5)
# Not Inserted:
# (Timestamp('2017-06-06 17:26:00'), Timestamp('2017-06-06 17:26:00'), None, 0.0, 0.0, 0.0, 0, 4939, -1.0, 622, 5)
# Not Inserted:
# (Timestamp('2017-07-19 16:27:00'), Timestamp('2017-07-19 16:27:00'), None, 0.0, 0.0, 0.0, 0, 4940, -1.0, 421, 5)
# Not Inserted:
# (Timestamp('2017-09-11 16:40:00'), Timestamp('2017-09-11 16:40:00'), None, 0.0, 0.0, 0.0, 0, 4941, -1.0, 912, 5)
# Not Inserted:
# (Timestamp('2017-09-25 17:00:00'), Timestamp('2017-09-25 17:00:00'), None, 0.0, 0.0, 0.0, 0, 4942, -1.0, 1493, 5)
# Not Inserted:
# (Timestamp('2017-05-10 13:46:00'), Timestamp('2017-05-10 13:46:00'), None, 0.0, 0.0, 0.0, 0, 4943, -1.0, 1180, 5)
# Not Inserted:
# (Timestamp('2017-12-04 09:44:00'), Timestamp('2017-12-04 09:44:00'), None, 0.0, 0.0, 0.0, 0, 4944, -1.0, 1012, 5)
# Not Inserted:
# (Timestamp('2017-09-26 17:00:00'), Timestamp('2017-09-26 17:00:00'), None, 0.0, 0.0, 0.0, 0, 4945, -1.0, 1494, 5)
# Not Inserted:
# (Timestamp('2017-04-03 16:31:00'), Timestamp('2017-04-03 16:31:00'), None, 0.0, 0.0, 0.0, 0, 4946, -1.0, 124, 5)
# Not Inserted:
# (Timestamp('2017-04-17 16:49:00'), Timestamp('2017-04-17 16:49:00'), None, 0.0, 0.0, 0.0, 0, 4947, -1.0, 1251, 5)
# Not Inserted:
# (Timestamp('2017-09-20 17:11:00'), Timestamp('2017-09-20 17:11:00'), None, 0.0, 0.0, 0.0, 0, 4948, -1.0, 1187, 5)
# Not Inserted:
# (Timestamp('2017-05-31 11:54:00'), Timestamp('2017-05-31 11:57:00'), None, 0.0, 0.0, 0.0, 3, 4949, -1.0, 752, 5)
# Not Inserted:
# (Timestamp('2017-09-18 17:56:00'), Timestamp('2017-09-18 17:56:00'), None, 0.0, 0.0, 0.0, 0, 4950, -1.0, 713, 5)
# Not Inserted:
# (Timestamp('2017-05-15 12:58:00'), Timestamp('2017-05-15 12:58:00'), None, 0.0, 0.0, 0.0, 0, 4951, -1.0, 1400, 5)
# Not Inserted:
# (Timestamp('2017-09-11 16:50:00'), Timestamp('2017-09-11 16:50:00'), None, 0.0, 0.0, 0.0, 0, 4952, -1.0, 225, 5)
# Not Inserted:
# (Timestamp('2017-12-29 12:52:00'), Timestamp('2017-12-29 12:52:00'), None, 0.0, 0.0, 0.0, 0, 4953, -1.0, 552, 5)
# Not Inserted:
# (Timestamp('2017-09-26 16:24:00'), Timestamp('2017-09-26 16:24:00'), None, 0.0, 0.0, 0.0, 0, 4954, -1.0, 586, 5)
# Not Inserted:
# (Timestamp('2017-06-06 16:55:00'), Timestamp('2017-06-06 16:56:00'), None, 0.0, 0.0, 0.0, 1, 4955, -1.0, 724, 5)
# Not Inserted:
# (Timestamp('2017-09-14 17:31:00'), Timestamp('2017-09-14 17:31:00'), None, 0.0, 0.0, 0.0, 0, 4956, -1.0, 581, 5)
# Not Inserted:
# (Timestamp('2017-09-15 16:51:00'), Timestamp('2017-09-15 16:51:00'), None, 0.0, 0.0, 0.0, 0, 4957, -1.0, 813, 5)
# Not Inserted:
# (Timestamp('2017-12-04 10:11:00'), Timestamp('2017-12-04 10:12:00'), None, 0.0, 0.0, 0.0, 1, 4958, -1.0, 537, 5)
# Not Inserted:
# (Timestamp('2017-07-31 15:22:00'), Timestamp('2017-07-31 15:22:00'), None, 0.0, 0.0, 0.0, 0, 4959, -1.0, 1495, 5)
# Not Inserted:
# (Timestamp('2017-06-09 16:18:00'), Timestamp('2017-06-09 16:18:00'), None, 0.0, 0.0, 0.0, 0, 4960, -1.0, 1496, 5)
# Not Inserted:
# (Timestamp('2017-12-18 23:39:00'), Timestamp('2017-12-18 23:39:00'), None, 0.0, 0.0, 0.0, 0, 4961, -1.0, 1497, 5)
# Not Inserted:
# (Timestamp('2017-05-02 13:52:00'), Timestamp('2017-05-02 13:52:00'), None, 0.0, 0.0, 0.0, 0, 4962, -1.0, 1441, 5)
# Not Inserted:
# (Timestamp('2017-09-20 17:03:00'), Timestamp('2017-09-20 17:04:00'), None, 0.0, 0.0, 0.0, 1, 4963, -1.0, 1498, 5)
# Not Inserted:
# (Timestamp('2017-12-18 16:29:00'), Timestamp('2017-12-18 16:29:00'), None, 0.0, 0.0, 0.0, 0, 4964, -1.0, 1499, 5)
# Not Inserted:
# (Timestamp('2017-11-16 16:31:00'), Timestamp('2017-11-16 16:31:00'), None, 0.0, 0.0, 0.0, 0, 4965, -1.0, 1500, 5)
# Not Inserted:
# (Timestamp('2017-05-30 11:34:00'), Timestamp('2017-05-30 11:34:00'), None, 0.0, 0.0, 0.0, 0, 4966, -1.0, 1501, 5)
# Not Inserted:
# (Timestamp('2017-12-18 15:21:00'), Timestamp('2017-12-18 15:21:00'), None, 0.0, 0.0, 0.0, 0, 4967, -1.0, 417, 5)
# Not Inserted:
# (Timestamp('2017-07-24 14:19:00'), Timestamp('2017-07-24 14:19:00'), None, 0.0, 0.0, 0.0, 0, 4974, -1.0, 503, 5)
# Not Inserted:
# (Timestamp('2017-09-18 17:53:00'), Timestamp('2017-09-18 17:53:00'), None, 0.0, 0.0, 0.0, 0, 4975, -1.0, 713, 5)
# Not Inserted:
# (Timestamp('2017-09-07 16:56:00'), Timestamp('2017-09-07 16:56:00'), None, 0.0, 0.0, 0.0, 0, 4977, -1.0, 484, 5)
# Not Inserted:
# (Timestamp('2017-06-23 16:20:00'), Timestamp('2017-06-23 16:21:00'), None, 0.0, 0.0, 0.0, 1, 4978, -1.0, 1015, 5)
# Not Inserted:
# (Timestamp('2017-11-08 08:47:00'), Timestamp('2017-11-08 08:47:00'), None, 0.0, 0.0, 0.0, 0, 4979, -1.0, 1504, 5)
# Not Inserted:
# (Timestamp('2017-06-06 17:00:00'), Timestamp('2017-06-06 17:00:00'), None, 0.0, 0.0, 0.0, 0, 4980, -1.0, 724, 5)
# Not Inserted:
# (Timestamp('2017-09-27 17:08:00'), Timestamp('2017-09-27 17:08:00'), None, 0.0, 0.0, 0.0, 0, 4981, -1.0, 1505, 5)
# Not Inserted:
# (Timestamp('2017-08-23 16:36:00'), Timestamp('2017-08-23 16:36:00'), None, 0.0, 0.0, 0.0, 0, 4983, -1.0, 429, 5)
# Not Inserted:
# (Timestamp('2017-05-12 16:17:00'), Timestamp('2017-05-12 16:17:00'), None, 0.0, 0.0, 0.0, 0, 4984, -1.0, 499, 5)
# Not Inserted:
# (Timestamp('2017-06-26 16:56:00'), Timestamp('2017-06-26 16:57:00'), None, 0.0, 0.0, 0.0, 1, 4985, -1.0, 1506, 5)
# Not Inserted:
# (Timestamp('2017-12-12 17:07:00'), Timestamp('2017-12-12 17:07:00'), None, 0.0, 0.0, 0.0, 0, 4986, -1.0, 1236, 5)
# Not Inserted:
# (Timestamp('2017-06-06 18:10:00'), Timestamp('2017-06-06 18:10:00'), None, 0.0, 0.0, 0.0, 0, 4987, -1.0, 1507, 5)
# Not Inserted:
# (Timestamp('2017-09-18 18:00:00'), Timestamp('2017-09-18 18:00:00'), None, 0.0, 0.0, 0.0, 0, 4988, -1.0, 183, 5)
# Not Inserted:
# (Timestamp('2017-04-28 16:50:00'), Timestamp('2017-04-28 16:50:00'), None, 0.0, 0.0, 0.0, 0, 4989, -1.0, 1508, 5)
# Not Inserted:
# (Timestamp('2017-07-27 16:22:00'), Timestamp('2017-07-27 16:22:00'), None, 0.0, 0.0, 0.0, 0, 4990, -1.0, 1276, 5)
# Not Inserted:
# (Timestamp('2017-12-14 16:38:00'), Timestamp('2017-12-14 16:38:00'), None, 0.0, 0.0, 0.0, 0, 4991, -1.0, 783, 5)
# Not Inserted:
# (Timestamp('2017-10-16 16:14:00'), Timestamp('2017-10-16 16:14:00'), None, 0.0, 0.0, 0.0, 0, 4992, -1.0, 598, 5)
# Not Inserted:
# (Timestamp('2017-08-28 10:02:00'), Timestamp('2017-08-28 10:02:00'), None, 0.0, 0.0, 0.0, 0, 4993, -1.0, 266, 5)
# Not Inserted:
# (Timestamp('2017-04-17 16:54:00'), Timestamp('2017-04-17 16:54:00'), None, 0.0, 0.0, 0.0, 0, 4994, -1.0, 1251, 5)
# Not Inserted:
# (Timestamp('2017-08-01 16:24:00'), Timestamp('2017-08-01 16:24:00'), None, 0.0, 0.0, 0.0, 0, 4995, -1.0, 468, 5)
# Not Inserted:
# (Timestamp('2017-12-18 18:43:00'), Timestamp('2017-12-18 18:43:00'), None, 0.0, 0.0, 0.0, 0, 4996, -1.0, 924, 5)
# Not Inserted:
# (Timestamp('2017-12-14 16:55:00'), Timestamp('2017-12-14 16:55:00'), None, 0.0, 0.0, 0.0, 0, 5053, -1.0, 566, 5)
# Not Inserted:
# (Timestamp('2017-05-16 17:29:00'), Timestamp('2017-05-16 17:29:00'), None, 0.0, 0.0, 0.0, 0, 5054, -1.0, 512, 5)
# Not Inserted:
# (Timestamp('2017-08-23 16:16:00'), Timestamp('2017-08-23 16:16:00'), None, 0.0, 0.0, 0.0, 0, 5055, -1.0, 682, 5)
# Not Inserted:
# (Timestamp('2017-12-14 16:45:00'), Timestamp('2017-12-14 16:46:00'), None, 0.0, 0.0, 0.0, 1, 5056, -1.0, 946, 5)
# Not Inserted:
# (Timestamp('2017-07-24 17:07:00'), Timestamp('2017-07-24 17:07:00'), None, 0.0, 0.0, 0.0, 0, 5057, -1.0, 1527, 5)
# Not Inserted:
# (Timestamp('2017-05-31 14:00:00'), Timestamp('2017-05-31 14:01:00'), None, 0.0, 0.0, 0.0, 1, 5058, -1.0, 1008, 5)
# Not Inserted:
# (Timestamp('2017-09-07 10:44:00'), Timestamp('2017-09-07 10:45:00'), None, 0.0, 0.0, 0.0, 1, 5059, -1.0, 681, 5)
# Not Inserted:
# (Timestamp('2017-04-19 16:27:00'), Timestamp('2017-04-19 16:28:00'), None, 0.0, 0.0, 0.0, 1, 5060, -1.0, 254, 5)
# Not Inserted:
# (Timestamp('2017-12-04 16:55:00'), Timestamp('2017-12-04 16:55:00'), None, 0.0, 0.0, 0.0, 0, 5061, -1.0, 16, 5)
# Not Inserted:
# (Timestamp('2017-10-20 17:21:00'), Timestamp('2017-10-20 17:21:00'), None, 0.0, 0.0, 0.0, 0, 5062, -1.0, 587, 5)
# Not Inserted:
# (Timestamp('2017-06-09 16:43:00'), Timestamp('2017-06-09 16:43:00'), None, 0.0, 0.0, 0.0, 0, 5063, -1.0, 390, 5)
# Not Inserted:
# (Timestamp('2017-03-27 16:55:00'), Timestamp('2017-03-27 16:55:00'), None, 0.0, 0.0, 0.0, 0, 5064, -1.0, 1528, 5)
# Not Inserted:
# (Timestamp('2017-09-18 17:12:00'), Timestamp('2017-09-18 17:12:00'), None, 0.0, 0.0, 0.0, 0, 5065, -1.0, 435, 5)
# Not Inserted:
# (Timestamp('2017-06-09 16:47:00'), Timestamp('2017-06-09 16:47:00'), None, 0.0, 0.0, 0.0, 0, 5066, -1.0, 566, 5)
# Not Inserted:
# ...
# Not Inserted:
# (Timestamp('2017-04-10 17:00:00'), Timestamp('2017-04-10 17:00:00'), None, 0.0, 0.0, 0.0, 0, 4895, -1.0, 1484, 9)
# Not Inserted:
# (Timestamp('2017-03-27 17:53:00'), Timestamp('2017-03-27 17:53:00'), None, 0.0, 0.0, 0.0, 0, 4899, -1.0, 375, 9)
# Not Inserted:
# (Timestamp('2017-05-12 12:52:00'), Timestamp('2017-05-12 12:52:00'), None, 0.0, 0.0, 0.0, 0, 4900, -1.0, 875, 9)
# Not Inserted:
# (Timestamp('2017-05-15 13:34:00'), Timestamp('2017-05-15 13:35:00'), None, 0.0, 0.0, 0.0, 1, 4901, -1.0, 970, 9)
# Not Inserted:
# (Timestamp('2017-12-18 17:40:00'), Timestamp('2017-12-18 17:41:00'), None, 0.0, 0.0, 0.0, 1, 4902, -1.0, 1209, 9)
# Not Inserted:
# (Timestamp('2017-09-25 16:24:00'), Timestamp('2017-09-25 16:24:00'), None, 0.0, 0.0, 0.0, 0, 4937, -1.0, 287, 9)
# Not Inserted:
# (Timestamp('2017-06-06 16:50:00'), Timestamp('2017-06-06 16:50:00'), None, 0.0, 0.0, 0.0, 0, 4938, -1.0, 724, 9)
# Not Inserted:
# (Timestamp('2017-06-06 17:26:00'), Timestamp('2017-06-06 17:26:00'), None, 0.0, 0.0, 0.0, 0, 4939, -1.0, 622, 9)
# Not Inserted:
# (Timestamp('2017-07-19 16:27:00'), Timestamp('2017-07-19 16:27:00'), None, 0.0, 0.0, 0.0, 0, 4940, -1.0, 421, 9)
# Not Inserted:
# (Timestamp('2017-09-11 16:40:00'), Timestamp('2017-09-11 16:40:00'), None, 0.0, 0.0, 0.0, 0, 4941, -1.0, 912, 9)
# Not Inserted:
# (Timestamp('2017-09-25 17:00:00'), Timestamp('2017-09-25 17:00:00'), None, 0.0, 0.0, 0.0, 0, 
# Not Inserted:
# (Timestamp('2017-11-16 16:31:00'), Timestamp('2017-11-16 16:31:00'), None, 0.0, 0.0, 0.0, 0, 4965, -1.0, 1500, 9)
# Not Inserted:
# (Timestamp('2017-05-30 11:34:00'), Timestamp('2017-05-30 11:34:00'), None, 0.0, 0.0, 0.0, 0, 4966, -1.0, 1501, 9)
# Not Inserted:
# (Timestamp('2017-12-18 15:21:00'), Timestamp('2017-12-18 15:21:00'), None, 0.0, 0.0, 0.0, 0, 4967, -1.0, 417, 9)
# Not Inserted:
# (Timestamp('2017-07-24 14:19:00'), Timestamp('2017-07-24 14:19:00'), None, 0.0, 0.0, 0.0, 0, 4974, -1.0, 503, 9)
# Not Inserted:
# (Timestamp('2017-09-18 17:53:00'), Timestamp('2017-09-18 17:53:00'), None, 0.0, 0.0, 0.0, 0, 4975, -1.0, 713, 9)
# Not Inserted:
# (Timestamp('2017-09-07 16:56:00'), Timestamp('2017-09-07 16:56:00'), None, 0.0, 0.0, 0.0, 0, 4977, -1.0, 484, 9)
# Not Inserted:
# (Timestamp('2017-06-23 16:20:00'), Timestamp('2017-06-23 16:21:00'), None, 0.0, 0.0, 0.0, 1, 4978, -1.0, 1015, 9)
# Not Inserted:
# (Timestamp('2017-11-08 08:47:00'), Timestamp('2017-11-08 08:47:00'), None, 0.0, 0.0, 0.0, 0, 4979, -1.0, 1504, 9)
# Not Inserted:
# (Timestamp('2017-06-06 17:00:00'), Timestamp('2017-06-06 17:00:00'), None, 0.0, 0.0, 0.0, 0, 4980, -1.0, 724, 9)
# Not Inserted:
# (Timestamp('2017-09-27 17:08:00'), Timestamp('2017-09-27 17:08:00'), None, 0.0, 0.0, 0.0, 0, 4981, -1.0, 1505, 9)
# Not Inserted:
# (Timestamp('2017-08-23 16:36:00'), Timestamp('2017-08-23 16:36:00'), None, 0.0, 0.0, 0.0, 0, 4983, -1.0, 429, 9)
# Not Inserted:
# (Timestamp('2017-05-12 16:17:00'), Timestamp('2017-05-12 16:17:00'), None, 0.0, 0.0, 0.0, 0, 4984, -1.0, 499, 9)
# Not Inserted:
# (Timestamp('2017-06-26 16:56:00'), Timestamp('2017-06-26 16:57:00'), None, 0.0, 0.0, 0.0, 1, 4985, -1.0, 1506, 9)
# Not Inserted:
# (Timestamp('2017-12-12 17:07:00'), Timestamp('2017-12-12 17:07:00'), None, 0.0, 0.0, 0.0, 0, 4986, -1.0, 1236, 9)
# Not Inserted:
# (Timestamp('2017-06-06 18:10:00'), Timestamp('2017-06-06 18:10:00'), None, 0.0, 0.0, 0.0, 0, 4987, -1.0, 1507, 9)
# Not Inserted:
# (Timestamp('2017-09-18 18:00:00'), Timestamp('2017-09-18 18:00:00'), None, 0.0, 0.0, 0.0, 0, 4988, -1.0, 183, 9)
# Not Inserted:
# (Timestamp('2017-04-28 16:50:00'), Timestamp('2017-04-28 16:50:00'), None, 0.0, 0.0, 0.0, 0, 4989, -1.0, 1508, 9)
# Not Inserted:
# (Timestamp('2017-07-27 16:22:00'), Timestamp('2017-07-27 16:22:00'), None, 0.0, 0.0, 0.0, 0, 4990, -1.0, 1276, 9)
# Not Inserted:
# (Timestamp('2017-12-14 16:38:00'), Timestamp('2017-12-14 16:38:00'), None, 0.0, 0.0, 0.0, 0, 4991, -1.0, 783, 9)
# Not Inserted:
# (Timestamp('2017-10-16 16:14:00'), Timestamp('2017-10-16 16:14:00'), None, 0.0, 0.0, 0.0, 0, 4992, -1.0, 598, 9)
# Not Inserted:
# (Timestamp('2017-08-28 10:02:00'), Timestamp('2017-08-28 10:02:00'), None, 0.0, 0.0, 0.0, 0, 4993, -1.0, 266, 9)
# Not Inserted:
# (Timestamp('2017-04-17 16:54:00'), Timestamp('2017-04-17 16:54:00'), None, 0.0, 0.0, 0.0, 0, 4994, -1.0, 1251, 9)
# Not Inserted:
# (Timestamp('2017-08-01 16:24:00'), Timestamp('2017-08-01 16:24:00'), None, 0.0, 0.0, 0.0, 0, 4995, -1.0, 468, 9)
# Not Inserted:
# (Timestamp('2017-12-18 18:43:00'), Timestamp('2017-12-18 18:43:00'), None, 0.0, 0.0, 0.0, 0, 4996, -1.0, 924, 9)
# Not Inserted:
# (Timestamp('2017-12-14 16:55:00'), Timestamp('2017-12-14 16:55:00'), None, 0.0, 0.0, 0.0, 0, 5053, -1.0, 566, 9)
# Not Inserted:
# (Timestamp('2017-05-16 17:29:00'), Timestamp('2017-05-16 17:29:00'), None, 0.0, 0.0, 0.0, 0, 5054, -1.0, 512, 9)
# Not Inserted:
# (Timestamp('2017-08-23 16:16:00'), Timestamp('2017-08-23 16:16:00'), None, 0.0, 0.0, 0.0, 0, 5055, -1.0, 682, 9)
# Not Inserted:
# (Timestamp('2017-12-14 16:45:00'), Timestamp('2017-12-14 16:46:00'), None, 0.0, 0.0, 0.0, 1, 5056, -1.0, 946, 9)
# Not Inserted:
# (Timestamp('2017-07-24 17:07:00'), Timestamp('2017-07-24 17:07:00'), None, 0.0, 0.0, 0.0, 0, 5057, -1.0, 1527, 9)
# Not Inserted:
# (Timestamp('2017-05-31 14:00:00'), Timestamp('2017-05-31 14:01:00'), None, 0.0, 0.0, 0.0, 1, 5058, -1.0, 1008, 9)
# Not Inserted:
# (Timestamp('2017-09-07 10:44:00'), Timestamp('2017-09-07 10:45:00'), None, 0.0, 0.0, 0.0, 1, 5059, -1.0, 681, 9)
# Not Inserted:
# (Timestamp('2017-04-19 16:27:00'), Timestamp('2017-04-19 16:28:00'), None, 0.0, 0.0, 0.0, 1, 5060, -1.0, 254, 9)
# Not Inserted:
# (Timestamp('2017-12-04 16:55:00'), Timestamp('2017-12-04 16:55:00'), None, 0.0, 0.0, 0.0, 0, 5061, -1.0, 16, 9)
# Not Inserted:
# (Timestamp('2017-10-20 17:21:00'), Timestamp('2017-10-20 17:21:00'), None, 0.0, 0.0, 0.0, 0, 5062, -1.0, 587, 9)
# Not Inserted:
# (Timestamp('2017-06-09 16:43:00'), Timestamp('2017-06-09 16:43:00'), None, 0.0, 0.0, 0.0, 0, 5063, -1.0, 390, 9)
# Not Inserted:
# (Timestamp('2017-03-27 16:55:00'), Timestamp('2017-03-27 16:55:00'), None, 0.0, 0.0, 0.0, 0, 5064, -1.0, 1528, 9)
# Not Inserted:
# (Timestamp('2017-09-18 17:12:00'), Timestamp('2017-09-18 17:12:00'), None, 0.0, 0.0, 0.0, 0, 5065, -1.0, 435, 9)
# Not Inserted:
# (Timestamp('2017-06-09 16:47:00'), Timestamp('2017-06-09 16:47:00'), None, 0.0, 0.0, 0.0, 0, 5066, -1.0, 566, 9)
# Not Inserted:
# (Timestamp('2017-09-15 16:39:00'), Timestamp('2017-09-15 16:39:00'), None, 0.0, 0.0, 0.0, 0, 5067, -1.0, 728, 9)
# Not Inserted:
# (Timestamp('2017-11-09 17:18:00'), Timestamp('2017-11-09 17:18:00'), None, 0.0, 0.0, 0.0, 0, 5068, -1.0, 539, 9)
# Not Inserted:
# (Timestamp('2017-06-06 16
-1.0, 512, 9)
# Not Inserted:
# (Timestamp('2017-10-27 16:56:00'), Timestamp('2017-10-27 16:56:00'), None, 0.0, 0.0, 0.0, 0, 5111, -1.0, 1539, 9)
# Not Inserted:
# (Timestamp('2017-06-20 10:15:00'), Timestamp('2017-06-20 10:15:00'), None, 0.0, 0.0, 0.0, 0, 5112, -1.0, 1540, 9)
# Not Inserted:
# (Timestamp('2017-09-07 16:56:00'), Timestamp('2017-09-07 16:56:00'), None, 0.0, 0.0, 0.0, 0, 5113, -1.0, 484, 9)
# Not Inserted:
# (Timestamp('2017-12-04 09:52:00'), Timestamp('2017-12-04 09:52:00'), None, 0.0, 0.0, 0.0, 0, 5114, -1.0, 1480, 9)
# Not Inserted:
# (Timestamp('2017-04-28 17:04:00'), Timestamp('2017-04-28 17:04:00'), None, 0.0, 0.0, 0.0, 0, 5115, -1.0, 1508, 9)
# Not Inserted:
# (Timestamp('2017-08-22 16:29:00'), Timestamp('2017-08-22 16:29:00'), None, 0.0, 0.0, 0.0, 0, 5116, -1.0, 346, 9)
# Not Inserted:
# (Timestamp('2017-03-24 16:37:00'), Timestamp('2017-03-24 16:38:00'), None, 0.0, 0.0, 0.0, 1, 5117, -1.0, 1541, 9)
# Not Inserted:
# (Timestamp('2017-09-11 16:32:00'), Timestamp('2017-09-11 16:32:00'), None, 0.0, 0.0, 0.0, 0, 5119, -1.0, 648, 9)
# Not Inserted:
# (Timestamp('2017-04-21 16:21:00'), Timestamp('2017-04-21 16:21:00'), None, 0.0, 0.0, 0.0, 0, 5120, -1.0, 1528, 9)
# Not Inserted:
# (Timestamp('2017-08-01 16:17:00'), Timestamp('2017-08-01 16:17:00'), None, 0.0, 0.0, 0.0, 0, 5121, -1.0, 468, 9)
# Not Inserted:
# (Timestamp('2017-06-26 17:00:00'), Timestamp('2017-06-26 17:01:00'), None, 0.0, 0.0, 0.0, 1, 5122, -1.0, 287, 9)

# %% [markdown]
# ## FactTransport

# %%
FactTransport = source_df[['loadsmart_id','carrier_name','lane','shipper_name','pickup_date',
                           'pickup_appointment_time','carrier_on_time_to_pickup','delivery_date',
                           'delivery_appointment_time','carrier_on_time_to_delivery','carrier_on_time_overall',
                           'mileage']]

FactTransport = FactTransport.rename(columns={'pickup_date':'pickup_datetime',
                         'pickup_appointment_time':'pickup_appointment_datetime',
                         'delivery_date':'delivery_datetime',
                         'carrier_on_time_to_pickup':'fl_carrier_on_time_to_pickup',
                         'delivery_appointment_time':'delivery_appointment_datetime',
                         'carrier_on_time_to_delivery':'fl_carrier_on_time_to_delivery',
                         'carrier_on_time_overall':'fl_carrier_on_time_overall',
                         'mileage':'mileage_value'
                        })

FactTransport['days_between_pickup_delivery'] = FactTransport['delivery_datetime'] - FactTransport['pickup_datetime'] 
FactTransport['days_between_pickup_delivery'] = FactTransport['days_between_pickup_delivery']/np.timedelta64(1,'D')
FactTransport['days_between_pickup_delivery'] = FactTransport['days_between_pickup_delivery'].astype(int)

FactTransport['hours_between_pickup_delivery'] = FactTransport['delivery_datetime'] - FactTransport['pickup_datetime'] 
FactTransport['hours_between_pickup_delivery'] = FactTransport['hours_between_pickup_delivery']/np.timedelta64(1,'h')
FactTransport['hours_between_pickup_delivery'] = FactTransport['hours_between_pickup_delivery'].astype(int)

FactTransport['sk_load_code'] = FactTransport['loadsmart_id'].map(DimLoad.set_index('loadsmart_id')['sk_code'])
FactTransport['sk_load_code'] = FactTransport['sk_load_code'].where(pd.notnull(FactTransport['sk_load_code']), -1)

FactTransport['sk_carrier_code'] = FactTransport['carrier_name'].map(DimCarrier.set_index('carrier_name')['sk_code'])
FactTransport['sk_carrier_code'] = FactTransport['sk_carrier_code'].where(pd.notnull(FactTransport['sk_carrier_code']), -1)

FactTransport['sk_route_code'] = FactTransport['lane'].map(DimRoute.set_index('lane')['sk_code'])
FactTransport['sk_route_code'] = FactTransport['sk_route_code'].where(pd.notnull(FactTransport['sk_route_code']), -1)

FactTransport['sk_shipper_code'] = FactTransport['shipper_name'].map(DimShipper.set_index('shipper_name')['sk_code'])
FactTransport['sk_shipper_code'] = FactTransport['sk_shipper_code'].where(pd.notnull(FactTransport['sk_shipper_code']), -1)

FactTransport = FactTransport.where(pd.notnull(FactTransport), None)

FactTransport = FactTransport.drop(columns=['loadsmart_id', 'carrier_name', 'lane', 'shipper_name'])

FactTransport
# Out:
#           pickup_datetime pickup_appointment_datetime  \
# 0     2017-12-15 11:00:00         2017-12-15 20:00:00
# 1     2017-11-21 14:00:00         2017-11-21 14:00:00
# 2     2017-06-03 02:00:00         2017-06-03 02:00:00
# 3     2017-11-22 17:00:00         2017-11-22 17:00:00
# 4     2017-09-26 17:00:00         2017-09-26 17:00:00
# ...                   ...                         ...
# 11678 2017-03-29 09:00:00         2017-03-29 17:00:00
# 11679 2017-09-12 23:00:00         2017-09-13 01:00:00
# 11680 2017-04-25 02:00:00         2017-04-25 02:00:00
# 11681 2017-08-02 11:00:00         2017-08-02 15:00:00
# 11682 2017-06-28 18:00:00         2017-06-28 18:00:00
#
#       fl_carrier_on_time_to_pickup   delivery_datetime  \
# 0                              1.0 2017-12-21 02:00:00
# 1                              1.0 2017-11-27 16:00:00
# 2                              1.0 2017-06-09 04:10:00
# 3                              1.0 2017-11-28 19:00:00
# 4                              1.0 2017-10-02 11:55:00
# ...                            ...                 ...
# 11678                         None 2017-03-28 09:14:00
# 11679                         None 2017-09-11 16:33:00
# 11680                         None 2017-04-24 09:49:00
# 11681                         None 2017-08-02 12:10:00
# 11682                         None 2017-06-28 18:26:00
#
#       delivery_appointment_datetime fl_carrier_on_time_to_delivery  \
# 0               2017-12-21 00:00:00                            1.0
# 1               2017-11-27 17:00:00                            1.0
# 2               2017-06-08 23:00:00                            1.0
# 3               2017-11-28 19:00:00                            1.0
# 4               2017-10-02 10:00:00                            1.0
# ...                             ...                            ...
# 11678           2017-03-30 14:00:00                           None
# 11679           2017-09-13 13:00:00                           None
# 11680           2017-04-25 13:30:00                           None
# 11681           2017-08-02 11:00:00                           None
# 11682           2017-06-30 14:00:00                           None
#
#       fl_carrier_on_time_overall mileage_value  days_between_pickup_delivery  \
# 0                            1.0        2753.5                             5
# 1                            1.0        2331.3                             6
# 2                            1.0        3013.4                             6
# 3                            1.0        2082.3                             6
# 4                            1.0        2847.7                             5
# ...                          ...           ...                           ...
# 11678                       None         666.3                             0
# 11679                       None         285.2                            -1
# 11680                       None         188.8                             0
# 11681                       None         300.0                             0
# 11682                       None         714.9                             0
#
#        hours_between_pickup_delivery  sk_load_code  sk_carrier_code  \
# 0                                135             1              1.0
# 1                                146             2            443.0
# 2                                146             3              3.0
# 3                                146             4              4.0
# 4                                138             5           1013.0
# ...                              ...           ...              ...
# 11678                            -23          5117             -1.0
# 11679                            -30          5119             -1.0
# 11680                            -16          5120             -1.0
# 11681                              1          5121             -1.0
# 11682                              0          5122             -1.0
#
#        sk_route_code  sk_shipper_code
# 0                  1                1
# 1                  2                2
# 2                  3                1
# 3                  4                2
# 4                  5                2
# ...              ...              ...
# 11678           1541                9
# 11679            648                9
# 11680           1528                9
# 11681            468                9
# 11682            287                9
#
# [11683 rows x 14 columns]

# %%
# creating column list for insertion
datacolumns = ", ".join([str('`'+i+'`') for i in FactTransport.columns.tolist()])

for i,row in FactTransport.iterrows():
    try:
        sql = "INSERT INTO `FactTransport` (" +datacolumns + ", `last_update`) VALUES (" + "%s,"*len(row) + "'"+ str(datetime.today())[:19]+ "')"
            
        connection.cursor().execute(sql, tuple(row))
        connection.commit()
    except:
        connection.commit()
        print('Not Inserted:')
        print(tuple(row))
# Out:
# Not Inserted:
# (Timestamp('2017-05-18 08:00:00'), Timestamp('2017-05-18 12:00:00'), 1.0, Timestamp('2017-05-18 16:00:00'), Timestamp('2017-05-18 16:30:00'), 1.0, 1.0, 59.7, 0, 8, 3860, -1.0, 1241, 65)
# Not Inserted:
# (Timestamp('2017-09-05 06:00:00'), Timestamp('2017-09-05 18:00:00'), None, Timestamp('2017-09-01 13:34:00'), Timestamp('2017-09-06 15:00:00'), None, None, 2895.4, -3, -88, 4814, -1.0, 104, 18)
# Not Inserted:
# (Timestamp('2017-05-07 15:00:00'), Timestamp('2017-05-07 15:00:00'), 1.0, Timestamp('2017-05-08 00:00:00'), Timestamp('2017-05-08 00:00:00'), 1.0, 1.0, 130.8, 0, 9, 4824, -1.0, 1089, 1)
# Not Inserted:
# (Timestamp('2017-10-27 12:00:00'), Timestamp('2017-10-27 14:00:00'), None, Timestamp('2017-10-25 16:49:00'), Timestamp('2017-10-27 18:00:00'), None, None, 111.9, -1, -43, 4831, -1.0, 1460, 31)
# Not Inserted:
# (Timestamp('2017-02-14 09:00:00'), Timestamp('2017-02-14 17:00:00'), None, Timestamp('2017-02-13 14:59:00'), Timestamp('2017-02-15 18:00:00'), None, None, 921.7, 0, -18, 4832, -1.0, 1461, 31)
# Not Inserted:
# (Timestamp('2017-04-04 09:00:00'), Timestamp('2017-04-04 17:00:00'), None, Timestamp('2017-03-31 10:36:00'), Timestamp('2017-04-04 17:00:00'), None, None, 87.6, -3, -94, 4833, -1.0, 1462, 97)
# Not Inserted:
# (Timestamp('2017
-1.0, 1371, 54)
# Not Inserted:
# (Timestamp('2017-12-06 16:00:00'), Timestamp('2017-12-06 16:00:00'), None, Timestamp('2017-12-06 09:21:00'), Timestamp('2017-12-11 06:00:00'), None, None, 2847.9, 0, -6, 4877, -1.0, 12, 4)
# Not Inserted:
# (Timestamp('2017-09-17 14:00:00'), Timestamp('2017-09-17 14:00:00'), None, Timestamp('2017-09-15 09:25:00'), Timestamp('2017-09-18 17:00:00'), None, None, 449.5, -2, -52, 4878, -1.0, 1473, 4)
# Not Inserted:
# (Timestamp('2017-07-02 10:00:00'), Timestamp('2017-07-02 12:00:00'), None, Timestamp('2017-06-27 17:25:00'), Timestamp('2017-07-03 12:00:00'), None, None, 749.8, -4, -112, 4879, -1.0, 269, 4)
# Not Inserted:
# (Timestamp('2018-01-02 12:00:00'), Timestamp('2018-01-02 14:00:00'), None, Timestamp('2017-12-29 13:03:00'), Timestamp('2018-01-03 04:00:00'), None, None, 328.8, -3, -94, 4880, -1.0, 552, 4)
# Not Inserted:
# (Timestamp('2017-06-27 09:00:00'), Timestamp('2017-06-27 17:00:00'), None, Timestamp('2017-06-26 15:25:00'), Timestamp('2017-06-27 17:00:00'), None, None, 165.5, 0, -17, 4881, -1.0, 418, 4)
# Not Inserted:
# (Timestamp('2017-06-12 16:00:00'), Timestamp('2017-06-12 16:00:00'), None, Timestamp('2017-06-09 17:42:00'), Timestamp('2017-06-13 17:00:00'), None, None, 219.3, -2, -70, 4882, -1.0, 1474, 4)
# Not Inserted:
# (Timestamp('2017-11-03 18:00:00'), Timestamp('2017-11-03 18:00:00'), None, Timestamp('2017-11-02 15:33:00'), Timestamp('2017-11-06 15:00:00'), None, None, 1122.2, -1, -26, 4883, -1.0, 1475, 4)
# Not Inserted:
# (Timestamp('2017-08-01 12:00:00'), Timestamp('2017-08-01 14:00:00'), None, Timestamp('2017-08-01 12:02:00'), Timestamp('2017-08-02 00:00:00'), None, None, 250.6, 0, 0, 4884, -1.0, 1476, 4)
# Not Inserted:
# (Timestamp('2017-12-20 15:00:00'), Timestamp('2017-12-20 17:00:00'), None, Timestamp('2017-12-19 08:42:00'), Timestamp('2017-12-21 07:00:00'), None, None, 334.9, -1, -30, 4885, -1.0, 1477, 4)
# Not Inserted:
# (Timestamp('2017-05-23 04:00:00'), Timestamp('2017-05-23 04:00:00'), None, Timestamp('2017-05-22 15:54:00'), Timestamp('2017-05-24 23:00:00'), None, None, 323.0, 0, -12, 4886, -1.0, 1284, 4)
# Not Inserted:
# (Timestamp('2017-07-12 09:00:00'), Timestamp('2017-07-12 17:00:00'), None, Timestamp('2017-07-10 11:53:00'), Timestamp('2017-07-13 06:00:00'), None, None, 89.5, -1, -45, 4887, -1.0, 512, 4)
# Not Inserted:
# (Timestamp('2017-09-29 16:00:00'), Timestamp('2017-09-29 16:00:00'), None, Timestamp('2017-09-27 16:53:00'), Timestamp('2017-10-02 15:00:00'), None, None, 351.9, -1, -47, 4888, -1.0, 1478, 4)
# Not Inserted:
# (Timestamp('2017-07-31 02:00:00'), Timestamp('2017-07-31 02:00:00'), None, Timestamp('2017-07-26 15:01:00'), Timestamp('2017-07-31 16:00:00'), None, None, 170.3, -4, -106, 4889, -1.0, 1479, 4)
# Not Inserted:
# (Timestamp('2017-10-24 17:00:00'), Timestamp('2017-10-24 17:00:00'), None, Timestamp('2017-10-23 11:04:00'), Timestamp('2017-10-26 23:00:00'), None, None, 1409.6, -1, -29, 4890, -1.0, 1480, 4)
# Not Inserted:
# (Timestamp('2017-06-09 09:00:00'), Timestamp('2017-06-09 17:00:00'), None, Timestamp('2017-06-07 11:48:00'), Timestamp('2017-06-09 12:00:00'), None, None, 266.6, -1, -45, 4891, -1.0, 724, 4)
# Not Inserted:
# (Timestamp('2017-09-11 22:00:00'), Timestamp('2017-09-12 00:00:00'), None, Timestamp('2017-09-11 08:59:00'), Timestamp('2017-09-12 15:00:00'), None, None, 357.5, 0, -13, 4892, -1.0, 1481, 4)
# Not Inserted:
# (Timestamp('2017-09-18 18:00:00'), Timestamp('2017-09-18 18:00:00'), None, Timestamp('2017-09-15 17:41:00'), Timestamp('2017-09-20 15:30:00'), None, None, 867.8, -3, -72, 4893, -1.0, 1482, 4)
# Not Inserted:
# (Timestamp('2017-09-29 16:00:00'), Timestamp('2017-09-29 16:00:00'), None, Timestamp('2017-09-28 11:08:00'), Timestamp('2017-10-02 16:00:00'), None, None, 1529.2, -1, -28, 4894, -1.0, 1483, 4)
# Not Inserted:
# (Timestamp('2017-04-17 17:00:00'), Timestamp('2017-04-17 17:00:00'), None, Timestamp('2017-04-14 09:57:00'), Timestamp('2017-04-18 11:00:00'), None, None, 199.5, -3, -79, 4895, -1.0, 1484, 4)
# Not Inserted:
# (Timestamp('2017-04-03 21:00:00'), Timestamp('2017-04-03 21:00:00'), None, Timestamp('2017-03-29 17:06:00'), Timestamp('2017-04-04 16:00:00'), None, None, 395.5, -5, -123, 4899, -1.0, 375, 4)
# Not Inserted:
# (Timestamp('2017-05-13 20:00:00'), Timestamp('2017-05-13 20:00:00'), None, Timestamp('2017-05-12 17:08:00'), Timestamp('2017-05-18 08:30:00'), None, None, 396.9, -1, -26, 4900, -1.0, 875, 4)
# Not Inserted:
# (Timestamp('2017-05-17 10:00:00'), Timestamp('2017-05-17 18:00:00'), None, Timestamp('2017-05-15 13:35:00'), Timestamp('2017-05-17 18:00:00'), None, None, 389.2, -1, -44, 4901, -1.0, 970, 4)
# Not Inserted:
# (Timestamp('2017-12-20 09:00:00'), Timestamp('2017-12-20 11:00:00'), None, Timestamp('2017-12-18 18:53:00'), Timestamp('2017-12-20 18:00:00'), None, None, 172.1, -1, -38, 4902, -1.0, 1209, 4)
# Not Inserted:
# (Timestamp('2017-12-07 15:00:00'), Timestamp('2017-12-07 15:00:00'), None, Timestamp('2017-12-07 08:16:00'), Timestamp('2017-12-08 08:00:00'), None, None, 1602.1, 0, -6, 4903, -1.0, 1486, 2)
# Not Inserted:
# (Timestamp('2017-12-19 16:00:00'), Timestamp('2017-12-19 16:00:00'), None, Timestamp('2017-12-19 16:59:00'), Timestamp('2017-12-23 14:00:00'), None, None, 1607.7, 0, 0, 4904, -1.0, 9, 2)
# Not Inserted:
# (Timestamp('2017-12-08 13:00:00'), Timestamp('2017-12-08 13:00:00'), None, Timestamp('2017-12-08 09:00:00'), Timestamp('2017-12-11 10:00:00'), None, None, 527.7, 0, -4, 4905, -1.0, 1487, 2)
# Not Inserted:
# (Timestamp('2017-10-11 15:00:00'), Timestamp('2017-10-11 17:00:00'), None, Timestamp('2017-10-09 11:49:00'), Timestamp('2017-10-12 11:00:00'), None, None, 1112.5, -2, -51, 4906, -1.0, 1488, 2)
# Not Inserted:
# (Timestamp('2017-12-19 16:00:00'), Timestamp('2017-12-19 16:00:00'), None, Timestamp('2017-12-19 16:59:00'), Timestamp('2017-12-23 14:00:00'), None, None, 1607.7, 0, 0, 4907, -1.0, 9, 2)
# Not Inserted:
# (Timestamp('2017-11-18 15:00:00'), Timestamp('2017-11-18 15:00:00'), None, Timestamp('2017-11-17 17:04:00'), Timestamp('2017-11-19 03:00:00'), None, None, 232.8, 0, -21, 4908, -1.0, 1121, 2)
# Not Inserted:
# (Timestamp('2017-12-08 13:00:00'), Timestamp('2017-12-08 13:00:00'), None, Timestamp('2017-12-08 09:01:00'), Timestamp('2017-12-12 10:00:00'), None, None, 2183.6, 0, -3, 4909, -1.0, 1489, 2)
# Not Inserted:
# (Timestamp('2017-10-30 13:00:00'), Timestamp('2017-10-30 13:00:00'), None, Timestamp('2017-10-31 08:56:00'), Timestamp('2017-10-31 16:00:00'), None, None, 565.7, 0, 19, 4910, -1.0, 267, 2)
# Not Inserted:
# (Timestamp('2017-10-25 12:00:00'), Timestamp('2017-10-25 12:00:00'), None, Timestamp('2017-10-24 16:03:00'), Timestamp('2017-10-26 12:00:00'), None, None, 565.7, 0, -19, 4911, -1.0, 267, 2)
# Not Inserted:
# (Timestamp('2017-10-12 14:00:00'), Timestamp('2017-10-12 16:00:00'), None, Timestamp('2017-10-09 12:11:00'), Timestamp('2017-10-13 12:00:00'), None, None, 410.8, -3, -73, 4914, -1.0, 998, 2)
# Not Inserted:
# (Timestamp('2017-10-26 15:00:00'), Timestamp('2017-10-26 15:00:00'), None, Timestamp('2017-10-23 14:04:00'), Timestamp('2017-10-31 09:00:00'), None, None, 2591.7, -3, -72, 4915, -1.0, 11, 2)
# Not Inserted:
# (Timestamp('2017-11-28 14:00:00'), Timestamp('2017-11-28 16:00:00'), None, Timestamp('2017-11-27 14:35:00'), Timestamp('2017-12-03 17:00:00'), None, None, 2777.3, 0, -23, 4916, -1.0, 14, 2)
# Not Inserted:
# (Timestamp('2017-12-06 13:00:00'), Timestamp('2017-12-06 13:00:00'), None, Timestamp('2017-12-06 15:41:00'), Timestamp('2017-12-07 17:00:00'), None, None, 536.4, 0, 2, 4917, -1.0, 94, 2)
# Not Inserted:
# (Timestamp('2017-11-26 15:00:00'), Timestamp('2017-11-26 17:00:00'), None, Timestamp('2017-11-21 16:42:00'), Timestamp('2017-11-29 02:00:00'), None, None, 1319.8, -4, -118, 4918, -1.0, 136, 2)
# Not Inserted:
# (Timestamp('2017-11-17 17:00:00'), Timestamp('2017-11-17 19:00:00'), None, Timestamp('2017-11-16 12:47:00'), Timestamp('2017-11-20 11:00:00'), None, None, 1478.7, -1, -28, 4919, -1.0, 126, 2)
# Not Inserted:
# (Timestamp('2017-12-14 12:00:00'), Timestamp('2017-12-14 12:00:00'), None, Timestamp('2017-12-13 18:14:00'), Timestamp('2017-12-16 14:00:00'), None, None, 1376.5, 0, -17, 4920, -1.0, 38, 2)
# Not Inserted:
# (Timestamp('2017-12-19 13:00:00'), Timestamp('2017-12-19 13:00:00'), None, Timestamp('2017-12-15 10:17:00'), Timestamp('2017-12-20 15:00:00'), None, None, 551.4, -4, -98, 4921, -1.0, 524, 2)
# Not Inserted:
# (Timestamp('2017-11-01 16:00:00'), Timestamp('2017-11-01 16:00:00'), None, Timestamp('2017-10-31 13:17:00'), Timestamp('2017-11-06 12:00:00'), None, None, 2551.9, -1, -26, 4922, -1.0, 78, 2)
# Not Inserted:
# (Timestamp('2017-11-17 20:00:00'), Timestamp('2017-11-17 22:00:00'), None, Timestamp('2017-11-10 12:53:00'), Timestamp('2017-11-20 07:00:00'), None, None, 1319.8, -7, -175, 4923, -1.0, 136, 2)
# Not Inserted:
# (Timestamp('2017-10-24 14:00:00'), Timestamp('2017-10-24 14:00:00'), None, Timestamp('2017-10-24 16:13:00'), Timestamp('2017-10-25 10:00:00'), None, None, 201.3, 0, 2, 4924, -1.0, 1148, 2)
# Not Inserted:
# (Timestamp('2017-12-07 13:00:00'), Timestamp('2017-12-07 15:00:00'), None, Timestamp('2017-12-06 09:41:00'), Timestamp('2017-12-09 01:00:00'), None, None, 783.9, -1, -27, 4925, -1.0, 264, 2)
# Not Inserted:
# (Timestamp('2017-12-08 13:00:00'), Timestamp('2017-12-08 13:00:00'), None, Timestamp('2017-12-08 08:32:00'), Timestamp('2017-12-12 13:00:00'), None, None, 2487.3, 0, -4, 4926, -1.0, 44, 2)
# Not Inserted:
# (Timestamp('2017-10-27 16:00:00'), Timestamp('2017-10-27 16:00:00'), None, Timestamp('2017-10-27 12:27:00'), Timestamp('2017-10-29 13:00:00'), None, None, 964.8, 0, -3, 4927, -1.0, 179, 2)
# Not Inserted:
# (Timestamp('2017-09-28 14:00:00'), Timestamp('2017-09-28 14:00:00'), None, Timestamp('2017-09-27 10:12:00'), Timestamp('2017-09-29 12:00:00'), None, None, 698.3, -1, -27, 4928, -1.0, 1492, 2)
# Not Inserted:
# (Timestamp('2017-11-22 14:00:00'), Timestamp('2017-11-22 14:00:00'), None, Timestamp('2017-11-20 09:48:00'), Timestamp('2017-11-25 02:00:00'), None, None, 1330.9, -2, -52, 4929, -1.0, 65, 2)
# Not Inserted:
# (Timestamp('2017-10-27 16:00:00'), Timestamp('2017-10-27 18:00:00'), None, Timestamp('2017-10-20 17:20:00'), Timestamp('2017-10-30 09:00:00'), None, None, 1464.4, -6, -166, 4930, -1.0, 263, 2)
# Not Inserted:
# (Timestamp('2017-11-08 14:00:00'), Timestamp('2017-11-08 16:00:00'), None, Timestamp('2017-11-02 10:35:00'), Timestamp('2017-11-13 04:00:00'), None, None, 2487.3, -6, -147, 4931, -1.0, 44, 2)
# Not Inserted:
# (Timestamp('2017-12-29 15:00:00'), Timestamp('2017-12-29 17:00:00'), None, Timestamp('2017-12-26 15:44:00'), Timestamp('2018-01-03 05:00:00'), None, None, 2487.3, -2, -71, 4932, -1.0, 44, 2)
# Not Inserted:
# (Timestamp('2017-11-30 17:00:00'), Timestamp('2017-11-30 17:00:00'), None, Timestamp('2017-11-30 16:34:00'), Timestamp('2017-12-02 10:00:00'), None, None, 1461.7, 0, 0, 4933, -1.0, 50, 2)
# Not Inserted:
# (Timestamp('2017-10-30 12:00:00'), Timestamp('2017-10-30 12:00:00'), None, Timestamp('2017-10-31 08:41:00'), Timestamp('2017-10-31 15:00:00'), None, None, 565.7, 0, 20, 4934, -1.0, 267, 2)
# Not Inserted:
# (Timestamp('2017
-1.0, 1251, 4)
# Not Inserted:
# (Timestamp('2017-09-23 06:04:00'), Timestamp('2017-09-23 08:04:00'), None, Timestamp('2017-09-20 18:32:00'), Timestamp('2017-09-24 01:04:00'), None, None, 402.7, -2, -59, 4948, -1.0, 1187, 4)
# Not Inserted:
# (Timestamp('2017-06-05 16:00:00'), Timestamp('2017-06-05 15:00:00'), None, Timestamp('2017-06-02 13:13:00'), Timestamp('2017-06-06 09:00:00'), None, None, 447.0, -3, -74, 4949, -1.0, 752, 4)
# Not Inserted:
# (Timestamp('2017-09-21 08:00:00'), Timestamp('2017-09-21 16:00:00'), None, Timestamp('2017-09-19 17:57:00'), Timestamp('2017-09-22 21:00:00'), None, None, 232.5, -1, -38, 4950, -1.0, 713, 4)
# Not Inserted:
# (Timestamp('2017-05-18 02:00:00'), Timestamp('2017-05-18 02:00:00'), None, Timestamp('2017-05-16 14:39:00'), Timestamp('2017-05-18 11:00:00'), None, None, 135.2, -1, -35, 4951, -1.0, 1400, 4)
# Not Inserted:
# (Timestamp('2017-09-13 12:00:00'), Timestamp('2017-09-13 14:00:00'), None, Timestamp('2017-09-11 16:53:00'), Timestamp('2017-09-15 16:00:00'), None, None, 1162.2, -1, -43, 4952, -1.0, 225, 4)
# Not Inserted:
# (Timestamp('2018-01-02 12:00:00'), Timestamp('2018-01-02 14:00:00'), None, Timestamp('2017-12-29 13:02:00'), Timestamp('2018-01-03 04:00:00'), None, None, 328.8, -3, -94, 4953, -1.0, 552, 4)
# Not Inserted:
# (Timestamp('2017-09-28 12:00:00'), Timestamp('2017-09-28 12:00:00'), None, Timestamp('2017-09-27 08:24:00'), Timestamp('2017-09-29 16:00:00'), None, None, 728.5, -1, -27, 4954, -1.0, 586, 4)
# Not Inserted:
# (Timestamp('2017-06-09 09:00:00'), Timestamp('2017-06-09 17:00:00'), None, Timestamp('2017-06-07 11:48:00'), Timestamp('2017-06-09 12:00:00'), None, None, 266.6, -1, -45, 4955, -1.0, 724, 4)
# Not Inserted:
# (Timestamp('2017-09-17 16:00:00'), Timestamp('2017-09-17 16:00:00'), None, Timestamp('2017-09-15 09:25:00'), Timestamp('2017-09-18 11:00:00'), None, None, 409.2, -2, -54, 4956, -1.0, 581, 4)
# Not Inserted:
# (Timestamp('2017-09-19 04:00:00'), Timestamp('2017-09-19 06:00:00'), None, Timestamp('2017-09-15 17:19:00'), Timestamp('2017-09-19 17:00:00'), None, None, 273.7, -3, -82, 4957, -1.0, 813, 4)
# Not Inserted:
# (Timestamp('2017-12-05 12:00:00'), Timestamp('2017-12-05 12:00:00'), None, Timestamp('2017-12-04 14:18:00'), Timestamp('2017-12-06 08:30:00'), None, None, 384.2, 0, -21, 4958, -1.0, 537, 4)
# Not Inserted:
# (Timestamp('2017-08-01 08:00:00'), Timestamp('2017-08-01 10:00:00'), None, Timestamp('2017-07-31 15:29:00'), Timestamp('2017-08-02 14:00:00'), None, None, 654.8, 0, -16, 4959, -1.0, 1495, 4)
# Not Inserted:
# (Timestamp('2017-06-13 17:00:00'), Timestamp('2017-06-13 17:00:00'), None, Timestamp('2017-06-12 14:18:00'), Timestamp('2017-06-15 08:30:00'), None, None, 1130.0, -1, -26, 4960, -1.0, 1496, 4)
# Not Inserted:
# (Timestamp('2017-12-20 12:00:00'), Timestamp('2017-12-20 14:00:00'), None, Timestamp('2017-12-19 14:52:00'), Timestamp('2017-12-20 20:00:00'), None, None, 148.5, 0, -21, 4961, -1.0, 1497, 4)
# Not Inserted:
# (Timestamp('2017-05-04 09:00:00'), Timestamp('2017-05-04 09:00:00'), None, Timestamp('2017-05-02 16:56:00'), Timestamp('2017-05-04 14:00:00'), None, None, 105.2, -1, -40, 4962, -1.0, 1441, 4)
# Not Inserted:
# (Timestamp('2017-09-23 13:00:00'), Timestamp('2017-09-23 15:00:00'), None, Timestamp('2017-09-20 18:12:00'), Timestamp('2017-09-24 18:00:00'), None, None, 629.5, -2, -66, 4963, -1.0, 1498, 4)
# Not Inserted:
# (Timestamp('2017-12-19 13:00:00'), Timestamp('2017-12-19 13:00:00'), None, Timestamp('2017-12-19 10:19:00'), Timestamp('2017-12-20 06:45:00'), None, None, 175.6, 0, -2, 4964, -1.0, 1499, 4)
# Not Inserted:
# (Timestamp('2017-11-18 19:00:00'), Timestamp('2017-11-18 19:00:00'), None, Timestamp('2017-11-20 09:16:00'), Timestamp('2017-11-20 11:00:00'), None, None, 735.9, 1, 38, 4965, -1.0, 1500, 4)
# Not Inserted:
# (Timestamp('2017-06-01 09:00:00'), Timestamp('2017-06-01 17:00:00'), None, Timestamp('2017-05-30 12:06:00'), Timestamp('2017-06-02 15:00:00'), None, None, 354.3, -1, -44, 4966, -1.0, 1501, 4)
# Not Inserted:
# (Timestamp('2017-12-18 21:00:00'), Timestamp('2017-12-18 21:00:00'), None, Timestamp('2017-12-18 15:22:00'), Timestamp('2017-12-21 03:00:00'), None, None, 653.9, 0, -5, 4967, -1.0, 417, 4)
# Not Inserted:
# (Timestamp('2017-03-07 09:00:00'), Timestamp('2017-03-07 17:00:00'), None, Timestamp('2017-03-02 10:09:00'), Timestamp('2017-03-07 18:00:00'), None, None, 524.5, -4, -118, 4968, -1.0, 1172, 102)
# Not Inserted:
# (Timestamp('2017-06-07 07:00:00'), Timestamp('2017-06-07 09:00:00'), None, Timestamp('2017-06-06 14:44:00'), Timestamp('2017-06-07 15:00:00'), None, None, 120.8, 0, -16, 4969, -1.0, 1433, 103)
# Not Inserted:
# (Timestamp('2017-08-25 09:00:00'), Timestamp('2017-08-25 15:00:00'), None, Timestamp('2017-08-21 10:08:00'), Timestamp('2017-08-28 09:00:00'), None, None, 566.3, -3, -94, 4970, -1.0, 1502, 103)
# Not Inserted:
# (Timestamp('2017-06-07 07:00:00'), Timestamp('2017-06-07 09:00:00'), None, Timestamp('2017-06-06 14:44:00'), Timestamp('2017-06-07 15:00:00'), None, None, 120.8, 0, -16, 4971, -1.0, 1433, 103)
# Not Inserted:
# (Timestamp('2017-06-07 07:00:00'), Timestamp('2017-06-07 09:00:00'), None, Timestamp('2017-06-06 14:43:00'), Timestamp('2017-06-07 15:00:00'), None, None, 120.8, 0, -16, 4972, -1.0, 1433, 103)
# Not Inserted:
# (Timestamp('2017-09-13 08:00:00'), Timestamp('2017-09-13 15:30:00'), None, Timestamp('2017-09-12 10:46:00'), Timestamp('2017-09-14 17:00:00'), None, None, 609.7, 0, -21, 4973, -1.0, 1503, 60)
# Not Inserted:
# (Timestamp('2017-06-07 07:00:00'), Timestamp('2017-06-07 09:00:00'), None, Timestamp('2017-06-06 14:44:00'), Timestamp('2017-06-07 15:00:00'), None, None, 120.8, 0, -16, 4969, -1.0, 1433, 104)
# Not Inserted:
# (Timestamp('2017-08-25 09:00:00'), Timestamp('2017-08-25 15:00:00'), None, Timestamp('2017-08-21 10:08:00'), Timestamp('2017-08-28 09:00:00'), None, None, 566.3, -3, -94, 4970, -1.0, 1502, 104)
# Not Inserted:
# (Timestamp('2017-06-07 07:00:00'), Timestamp('2017-06-07 09:00:00'), None, Timestamp('2017-06-06 14:44:00'), Timestamp('2017-06-07 15:00:00'), None, None, 120.8, 0, -16, 4971, -1.0, 1433, 104)
# Not Inserted:
# (Timestamp('2017-06-07 07:00:00'), Timestamp('2017-06-07 09:00:00'), None, Timestamp('2017-06-06 14:43:00'), Timestamp('2017-06-07 15:00:00'), None, None, 120.8, 0, -16, 4972, -1.0, 1433, 104)
# Not Inserted:
# (Timestamp('2017-07-31 09:00:00'), Timestamp('2017-07-31 11:00:00'), None, Timestamp('2017-07-24 14:24:00'), Timestamp('2017-07-31 18:00:00'), None, None, 173.3, -6, -162, 4974, -1.0, 503, 4)
# Not Inserted:
# (Timestamp('2017-09-21 08:00:00'), Timestamp('2017-09-21 15:00:00'), None, Timestamp('2017-09-19 17:58:00'), Timestamp('2017-09-22 21:00:00'), None, None, 232.5, -1, -38, 4975, -1.0, 713, 4)
# Not Inserted:
# (Timestamp('2017-09-08 12:00:00'), Timestamp('2017-09-08 14:00:00'), None, Timestamp('2017-09-07 16:57:00'), Timestamp('2017-09-09 01:00:00'), None, None, 252.6, 0, -19, 4977, -1.0, 484, 4)
# Not Inserted:
# (Timestamp('2017-06-27 21:00:00'), Timestamp('2017-06-27 21:00:00'), None, Timestamp('2017-06-26 15:07:00'), Timestamp('2017-06-28 17:00:00'), None, None, 557.6, -1, -29, 4978, -1.0, 1015, 4)
# Not Inserted:
# (Timestamp('2017-11-09 17:00:00'), Timestamp('2017-11-09 17:00:00'), None, Timestamp('2017-11-09 12:49:00'), Timestamp('2017-11-14 12:00:00'), None, None, 3081.4, 0, -4, 4979, -1.0, 1504, 4)
# Not Inserted:
# (Timestamp('2017-06-09 02:00:00'), Timestamp('2017-06-09 02:00:00'), None, Timestamp('2017-06-07 11:48:00'), Timestamp('2017-06-09 12:00:00'), None, None, 266.6, -1, -38, 4980, -1.0, 724, 4)
# Not Inserted:
# (Timestamp('2017-10-01 14:00:00'), Timestamp('2017-10-01 14:00:00'), None, Timestamp('2017-09-29 15:00:00'), Timestamp('2017-10-04 12:00:00'), None, None, 1569.7, -1, -47, 4981, -1.0, 1505, 4)
# Not Inserted:
# (Timestamp('2017-08-26 18:00:00'), Timestamp('2017-08-26 20:00:00'), None, Timestamp('2017-08-23 17:07:00'), Timestamp('2017-08-27 18:00:00'), None, None, 516.3, -3, -72, 4983, -1.0, 429, 4)
# Not Inserted:
# (Timestamp('2017-05-16 09:00:00'), Timestamp('2017-05-16 17:00:00'), None, Timestamp('2017-05-12 16:33:00'), Timestamp('2017-05-17 17:00:00'), None, None, 661.4, -3, -88, 4984, -1.0, 499, 4)
# Not Inserted:
# (Timestamp('2017-06-28 18:00:00'), Timestamp('2017-06-28 18:00:00'), None, Timestamp('2017-06-27 16:31:00'), Timestamp('2017-06-29 15:00:00'), None, None, 378.2, -1, -25, 4985, -1.0, 1506, 4)
# Not Inserted:
# (Timestamp('2017-12-13 18:00:00'), Timestamp('2017-12-13 20:00:00'), None, Timestamp('2017-12-12 17:24:00'), Timestamp('2017-12-14 04:00:00'), None, None, 203.4, -1, -24, 4986, -1.0, 1236, 4)
# Not Inserted:
# (Timestamp('2017-06-08 12:00:00'), Timestamp('2017-06-08 20:00:00'), None, Timestamp('2017-06-07 14:18:00'), Timestamp('2017-06-08 20:00:00'), None, None, 442.6, 0, -21, 4987, -1.0, 1507, 4)
# Not Inserted:
# (Timestamp('2017-09-19 12:00:00'), Timestamp('2017-09-19 14:00:00'), None, Timestamp('2017-09-18 18:10:00'), Timestamp('2017-09-20 22:00:00'), None, None, 739.3, 0, -17, 4988, -1.0, 183, 4)
# Not Inserted:
# (Timestamp('2017-05-03 11:00:00'), Timestamp('2017-05-03 19:00:00'), None, Timestamp('2017-04-28 17:00:00'), Timestamp('2017-05-06 17:00:00'), None, None, 1769.0, -4, -114, 4989, -1.0, 1508, 4)
# Not Inserted:
# (Timestamp('2017-07-31 07:00:00'), Timestamp('2017-07-31 10:00:00'), None, Timestamp('2017-07-28 13:56:00'), Timestamp('2017-07-31 13:00:00'), None, None, 82.3, -2, -65, 4990, -1.0, 1276, 4)
# Not Inserted:
# (Timestamp('2017-12-17 23:00:00'), Timestamp('2017-12-18 01:00:00'), None, Timestamp('2017-12-14 17:27:00'), Timestamp('2017-12-19 23:00:00'), None, None, 1064.6, -3, -77, 4991, -1.0, 783, 4)
# Not Inserted:
# (Timestamp('2017-10-17 19:00:00'), Timestamp('2017-10-17 19:00:00'), None, Timestamp('2017-10-16 17:55:00'), Timestamp('2017-10-18 12:00:00'), None, None, 397.1, -1, -25, 4992, -1.0, 598, 4)
# Not Inserted:
# (Timestamp('2017-08-29 23:00:00'), Timestamp('2017-08-30 01:00:00'), None, Timestamp('2017-08-28 10:02:00'), Timestamp('2017-08-31 21:00:00'), None, None, 1026.7, -1, -36, 4993, -1.0, 266, 4)
# Not Inserted:
# (Timestamp('2017-04-19 02:00:00'), Timestamp('2017-04-19 02:00:00'), None, Timestamp('2017-04-18 11:52:00'), Timestamp('2017-04-19 17:00:00'), None, None, 387.7, 0, -14, 4994, -1.0, 1251, 4)
# Not Inserted:
# (Timestamp('2017-08-02 11:00:00'), Timestamp('2017-08-02 15:00:00'), None, Timestamp('2017-08-02 12:11:00'), Timestamp('2017-08-03 11:00:00'), None, None, 300.0, 0, 1, 4995, -1.0, 468, 4)
# Not Inserted:
# (Timestamp('2017-12-20 09:00:00'), Timestamp('2017-12-20 11:00:00'), None, Timestamp('2017-12-19 08:38:00'), Timestamp('2017-12-21 13:00:00'), None, None, 380.5, -1, -24, 4996, -1.0, 924, 4)
# Not Inserted:
# Not Inserted:
# (Timestamp('2017-01-17 09:00:00'), Timestamp('2017-01-17 17:00:00'), None, Timestamp('2017-01-12 11:15:00'), Timestamp('2017-01-17 17:00:00'), None, None, 230.0, -4, -117, 5037, -1.0, 1358, 35)
# Not Inserted:
# (Timestamp('2017-09-20 12:00:00'), Timestamp('2017-09-20 14:00:00'), None, Timestamp('2017-09-15 16:17:00'), Timestamp('2017-09-25 11:00:00'), None, None, 2809.8, -4, -115, 5038, -1.0, 22, 11)
# Not Inserted:
# (Timestamp('2017-09-21 11:00:00'), Timestamp('2017-09-21 20:00:00'), None, Timestamp('2017-09-19 11:38:00'), Timestamp('2017-09-26 17:00:00'), None, None, 2809.8, -1, -47, 5039, -1.0, 22, 11)
# Not Inserted:
# (Timestamp('2017-11-03 09:00:00'), Timestamp('2017-11-03 17:00:00'), None, Timestamp('2017-11-03 16:54:00'), Timestamp('2017-11-06 12:00:00'), None, None, 895.7, 0, 7, 5040, -1.0, 1524, 2)
# Not Inserted:
# (Timestamp('2017-09-28 11:00:00'), Timestamp('2017-09-28 13:00:00'), None, Timestamp('2017-09-27 11:41:00'), Timestamp('2017-09-29 13:00:00'), None, None, 263.2, 0, -23, 5041, -1.0, 1456, 2)
# Not Inserted:
# (Timestamp('2017-12-13 13:00:00'), Timestamp('2017-12-13 15:00:00'), None, Timestamp('2017-12-11 08:54:00'), Timestamp('2017-12-14 17:00:00'), None, None, 614.9, -2, -52, 5042, -1.0, 226, 2)
# Not Inserted:
# (Timestamp('2017-10-09 15:00:00'), Timestamp('2017-10-09 15:00:00'), None, Timestamp('2017-10-06 11:15:00'), Timestamp('2017-10-10 07:00:00'), None, None, 463.2, -3, -75, 5043, -1.0, 585, 2)
# Not Inserted:
# (Timestamp('2017-11-03 15:00:00'), Timestamp('2017-11-03 15:00:00'), None, Timestamp('2017-11-03 16:54:00'), Timestamp('2017-11-06 11:00:00'), None, None, 895.7, 0, 1, 5044, -1.0, 1524, 2)
# Not Inserted:
# (Timestamp('2017-10-27 16:00:00'), Timestamp('2017-10-27 18:00:00'), None, Timestamp('2017-10-20 17:20:00'), Timestamp('2017-10-30 09:00:00'), None, None, 1464.4, -6, -166, 5045, -1.0, 263, 2)
# Not Inserted:
# (Timestamp('2017-09-20 09:00:00'), Timestamp('2017-09-20 17:00:00'), None, Timestamp('2017-09-15 17:28:00'), Timestamp('2017-09-21 17:00:00'), None, None, 634.5, -4, -111, 5046, -1.0, 1525, 2)
# Not Inserted:
# (Timestamp('2017-10-25 12:00:00'), Timestamp('2017-10-25 12:00:00'), None, Timestamp('2017-10-24 16:04:00'), Timestamp('2017-10-26 05:00:00'), None, None, 565.7, 0, -19, 5047, -1.0, 267, 2)
# Not Inserted:
# (Timestamp('2017-10-20 15:00:00'), Timestamp('2017-10-20 15:00:00'), None, Timestamp('2017-10-20 10:36:00'), Timestamp('2017-10-23 11:00:00'), None, None, 1277.4, 0, -4, 5048, -1.0, 116, 2)
# Not Inserted:
# (Timestamp('2017-02-01 10:00:00'), Timestamp('2017-02-01 18:00:00'), None, Timestamp('2017-01-26 16:13:00'), Timestamp('2017-02-02 18:00:00'), None, None, 939.7, -5, -137, 5049, -1.0, 1526, 46)
# Not Inserted:
# (Timestamp('2017-02-16 10:00:00'), Timestamp('2017-02-16 18:00:00'), None, Timestamp('2017-02-13 11:07:00'), Timestamp('2017-02-17 18:00:00'), None, None, 641.2, -2, -70, 5050, -1.0, 1125, 46)
# Not Inserted:
# (Timestamp('2017-04-06 10:00:00'), Timestamp('2017-04-06 18:00:00'), None, Timestamp('2017-04-04 11:15:00'), Timestamp('2017-04-07 18:00:00'), None, None, 653.4, -1, -46, 5051, -1.0, 555, 46)
# Not Inserted:
# (Timestamp('2017-07-19 08:30:00'), Timestamp('2017-07-19 11:30:00'), None, Timestamp('2017-07-18 15:29:00'), Timestamp('2017-07-20 08:00:00'), None, None, 598.7, 0, -17, 5052, -1.0, 902, 19)
# Not Inserted:
# (Timestamp('2017-12-20 15:00:00'), Timestamp('2017-12-20 15:00:00'), None, Timestamp('2017-12-20 08:56:00'), Timestamp('2017-12-21 08:30:00'), None, None, 364.9, 0, -6, 5053, -1.0, 566, 4)
# Not Inserted:
# (Timestamp('2017-05-17 16:00:00'), Timestamp('2017-05-17 16:00:00'), None, Timestamp('2017-05-18 10:12:00'), Timestamp('2017-05-18 13:30:00'), None, None, 86.1, 0, 18, 5054, -1.0, 512, 4)
# Not Inserted:
# (Timestamp('2017-08-25 10:00:00'), Timestamp('2017-08-25 12:00:00'), None, Timestamp('2017-08-23 16:47:00'), Timestamp('2017-08-26 10:00:00'), None, None, 519.8, -1, -41, 5055, -1.0, 682, 4)
# Not Inserted:
# (Timestamp('2017-12-19 03:00:00'), Timestamp('2017-12-19 05:00:00'), None, Timestamp('2017-12-15 10:28:00'), Timestamp('2017-12-20 13:00:00'), None, None, 438.7, -3, -88, 5056, -1.0, 946, 4)
# Not Inserted:
# (Timestamp('2017-07-26 18:00:00'), Timestamp('2017-07-26 18:00:00'), None, Timestamp('2017-07-27 15:29:00'), Timestamp('2017-08-01 11:30:00'), None, None, 2114.6, 0, 21, 5057, -1.0, 1527, 4)
# Not Inserted:
# (Timestamp('2017-06-01 16:00:00'), Timestamp('2017-06-01 16:00:00'), None, Timestamp('2017-05-31 16:32:00'), Timestamp('2017-06-02 14:00:00'), None, None, 293.0, 0, -23, 5058, -1.0, 1008, 4)
# Not Inserted:
# (Timestamp('2017-09-08 08:00:00'), Timestamp('2017-09-08 10:00:00'), None, Timestamp('2017-09-07 10:50:00'), Timestamp('2017-09-08 23:00:00'), None, None, 314.3, 0, -21, 5059, -1.0, 681, 4)
# Not Inserted:
# (Timestamp('2017-04-22 10:00:00'), Timestamp('2017-04-22 18:00:00'), None, Timestamp('2017-04-19 16:31:00'), Timestamp('2017-04-24 17:00:00'), None, None, 1225.0, -2, -65, 5060, -1.0, 254, 4)
# Not Inserted:
# (Timestamp('2017-12-06 21:00:00'), Timestamp('2017-12-06 21:00:00'), None, Timestamp('2017-12-05 17:49:00'), Timestamp('2017-12-11 23:00:00'), None, None, 2733.2, -1, -27, 5061, -1.0, 16, 4)
# Not Inserted:
# (Timestamp('2017-10-24 17:00:00'), Timestamp('2017-10-24 17:00:00'), None, Timestamp('2017-10-20 17:57:00'), Timestamp('2017-10-25 15:30:00'), None, None, 559.7, -3, -95, 5062, -1.0, 587, 4)
# Not Inserted:
# (Timestamp('2017-06-13 14:00:00'), Timestamp('2017-06-13 14:00:00'), None, Timestamp('2017-06-12 15:01:00'), Timestamp('2017-06-14 13:30:00'), None, None, 613.1, 0, -22, 5063, -1.0, 390, 4)
# Not Inserted:
# (Timestamp('2017-04-03 21:00:00'), Timestamp('2017-04-03 21:00:00'), None, Timestamp('2017-03-31 16:05:00'), Timestamp('2017-04-04 09:00:00'), None, None, 188.8, -3, -76, 5064, -1.0, 1528, 4)
# Not Inserted:
# (Timestamp('2017-09-21 08:03:00'), Timestamp('2017-09-21 10:03:00'), None, Timestamp('2017-09-18 17:45:00'), Timestamp('2017-09-22 22:03:00'), None, None, 825.3, -2, -62, 5065, -1.0, 435, 4)
# Not Inserted:
# (Timestamp('2017-06-13 09:00:00'), Timestamp('2017-06-13 17:00:00'), None, Timestamp('2017-06-09 16:48:00'), Timestamp('2017-06-13 17:00:00'), None, None, 364.9, -3, -88, 5066, -1.0, 566, 4)
# Not Inserted:
# (Timestamp('2017-09-18 23:00:00'), Timestamp('2017-09-19 01:00:00'), None, Timestamp('2017-09-15 17:19:00'), Timestamp('2017-09-19 15:30:00'), None, None, 527.8, -3, -77, 5067, -1.0, 728, 4)
# Not Inserted:
# ...
# Not Inserted:
# (Timestamp('2017-06-08 12:00:00'), Timestamp('2017-06-08 20:00:00'), None, Timestamp('2017-06-07 14:18:00'), Timestamp('2017-06-08 20:00:00'), None, None, 442.6, 0, -21, 4987, -1.0, 1507, 9)
# Not Inserted:
# (Timestamp('2017-09-19 12:00:00'), Timestamp('2017-09-19 14:00:00'), None, Timestamp('2017-09-18 18:10:00'), Timestamp('2017-09-20 22:00:00'), None, None, 739.3, 0, -17, 4988, -1.0, 183, 9)
# Not Inserted:
# (Timestamp('2017-05-03 11:00:00'), Timestamp('2017-05-03 19:00:00'), None, Timestamp('2017-04-28 17:00:00'), Timestamp('2017-05-06 17:00:00'), None, None, 1769.0, -4, -114, 4989, -1.0, 1508, 9)
# Not Inserted:
# (Timestamp('2017-07-31 07:00:00'), Timestamp('2017-07-31 10:00:00'), None, Timestamp('2017-07-28 13:56:00'), Timestamp('2017-07-31 13:00:00'), None, None, 82.3, -2, -65, 4990, -1.0, 1276, 9)
# Not Inserted:
# (Timestamp('2017-12-17 23:00:00'), Timestamp('2017-12-18 01:00:00'), None, Timestamp('2017-12-14 17:27:00'), Timestamp('2017-12-19 23:00:00'), None, None, 1064.6, -3, -77, 4991, -1.0, 783, 9)
# Not Inserted:
# (Timestamp('2017-10-17 19:00:00'), Timestamp('2017-10-17 19:00:00'), None, Timestamp('2017-10-16 17:55:00'), Timestamp('2017-10-18 12:00:00'), None, None, 397.1, -1, -25, 4992, -1.0, 598, 9)
# Not Inserted:
# (Timestamp('2017-08-29 23:00:00'), Timestamp('2017-08-30 01:00:00'), None, Timestamp('2017-08-28 10:02:00'), Timestamp('2017-08-31 21:00:00'), None, None, 1026.7, -1, -36, 4993, -1.0, 266, 9)
# Not Inserted:
# (Timestamp('2017-04-19 02:00:00'), Timestamp('2017-04-19 02:00:00'), None, Timestamp('2017-04-18 11:52:00'), Timestamp('2017-04-19 17:00:00'), None, None, 387.7, 0, -14, 4994, -1.0, 1251, 9)
# Not Inserted:
# (Timestamp('2017-08-02 11:00:00'), Timestamp('2017-08-02 15:00:00'), None, Timestamp('2017-08-02 12:11:00'), Timestamp('2017-08-03 11:00:00'), None, None, 300.0, 0, 1, 4995, -1.0, 468, 9)
# Not Inserted:
# (Timestamp('2017-12-20 09:00:00'), Timestamp('2017-12-20 11:00:00'), None, Timestamp('2017-12-19 08:38:00'), Timestamp('2017-12-21 13:00:00'), None, None, 380.5, -1, -24, 4996, -1.0, 924, 9)
# Not Inserted:
# (Timestamp('2017-12-20 15:00:00'), Timestamp('2017-12-20 15:00:00'), None, Timestamp('2017-12-20 08:56:00'), Timestamp('2017-12-21 08:30:00'), None, None, 364.9, 0, -6, 5053, -1.0, 566, 9)
# Not Inserted:
# (Timestamp('2017-05-17 16:00:00'), Timestamp('2017-05-17 16:00:00'), None, Timestamp('2017-05-18 10:12:00'), Timestamp('2017-05-18 13:30:00'), None, None, 86.1, 0, 18, 5054, -1.0, 512, 9)
# Not Inserted:
# (Timestamp('2017-08-25 10:00:00'), Timestamp('2017-08-25 12:00:00'), None, Timestamp('2017-08-23 16:47:00'), Timestamp('2017-08-26 10:00:00'), None, None, 519.8, -1, -41, 5055, -1.0, 682, 9)
# Not Inserted:
# (Timestamp('2017-12-19 03:00:00'), Timestamp('2017-12-19 05:00:00'), None, Timestamp('2017-12-15 10:28:00'), Timestamp('2017-12-20 13:00:00'), None, None, 438.7, -3, -88, 5056, -1.0, 946, 9)
# Not Inserted:
# (Timestamp('2017-07-26 18:00:00'), Timestamp('2017-07-26 18:00:00'), None, Timestamp('2017-07-27 15:29:00'), Timestamp('2017-08-01 11:30:00'), None, None, 2114.6, 0, 21, 5057, -1.0, 1527, 9)
# Not Inserted:
# (Timestamp('2017-06-01 16:00:00'), Timestamp('2017-06-01 16:00:00'), None, Timestamp('2017-05-31 16:32:00'), Timestamp('2017-06-02 14:00:00'), None, None, 293.0, 0, -23, 5058, -1.0, 1008, 9)
# Not Inserted:
# (Timestamp('2017-09-08 08:00:00'), Timestamp('2017-09-08 10:00:00'), None, Timestamp('2017-09-07 10:50:00'), Timestamp('2017-09-08 23:00:00'), None, None, 314.3, 0, -21, 5059, -1.0, 681, 9)
# Not Inserted:
# (Timestamp('2017-04-22 10:00:00'), Timestamp('2017-04-22 18:00:00'), None, Timestamp('2017-04-19 16:31:00'), Timestamp('2017-04-24 17:00:00'), None, None, 1225.0, -2, -65, 5060, -1.0, 254, 9)
# Not Inserted:
# (Timestamp('2017-12-06 21:00:00'), Timestamp('2017-12-06 21:00:00'), None, Timestamp('2017-12-05 17:49:00'), Timestamp('2017-12-11 23:00:00'), None, None, 2733.2, -1, -27, 5061, -1.0, 16, 9)
# Not Inserted:
# (Timestamp('2017-10-24 17:00:00'), Timestamp('2017-10-24 17:00:00'), None, Timestamp('2017-10-20 17:57:00'), Timestamp('2017-10-25 15:30:00'), None, None, 559.7, -3, -95, 5062, -1.0, 587, 9)
# Not Inserted:
# (Timestamp('2017-06-13 14:00:00'), Timestamp('2017-06-13 14:00:00'), None, Timestamp('2017-06-12 15:01:00'), Timestamp('2017-06-14 13:30:00'), None, None, 613.1, 0, -22, 5063, -1.0, 390, 9)
# Not Inserted:
# (Timestamp('2017-04-03 21:00:00'), Timestamp('2017-04-03 21:00:00'), None, Timestamp('2017-03-31 16:05:00'), Timestamp('2017-04-04 09:00:00'), None, None, 188.8, -3, -76, 5064, -1.0, 1528, 9)
# Not Inserted:
# (Timestamp('2017-09-21 08:03:00'), Timestamp('2017-09-21 10:03:00'), None, Timestamp('2017-09-18 17:45:00'), Timestamp('2017-09-22 22:03:00'), None, None, 825.3, -2, -62, 5065, -1.0, 435, 9)
# Not Inserted:
# (Timestamp('2017-06-13 09:00:00'), Timestamp('2017-06-13 17:00:00'), None, Timestamp('2017-06-09 16:48:00'), Timestamp('2017-06-13 17:00:00'), None, None, 364.9, -3, -88, 5066, -1.0, 566, 9)
# Not Inserted:
# (Timestamp('2017-09-18 23:00:00'), Timestamp('2017-09-19 01:00:00'), None, Timestamp('2017-09-15 17:19:00'), Timestamp('2017-09-19 15:30:00'), None, None, 527.8, -3, -77, 5067, -1.0, 728, 9)
# Not Inserted:
# (Timestamp('2017-11-13 00:00:00'), Timestamp('2017-11-13 00:00:00'), None, Timestamp('2017-11-10 12:33:00'), Timestamp('2017-11-14 10:00:00'), None, None, 802.0, -2, -59, 5068, -1.0, 539, 9)
# Not Inserted:
# (Timestamp('2017-06-09 09:00:00'), Timestamp('2017-06-09 17:00:00'), None, Timestamp('2017-06-07 11:49:00'), Timestamp('2017-06-09 12:00:00'), None, None, 266.6, -1, -45, 5069, -1.0, 724, 9)
# Not Inserted:
# (Timestamp('2017-04-17 16:00:00'), Timestamp('2017-04-17 16:00:00'), None, Timestamp('2017-04-14 09:56:00'), Timestamp('2017-04-18 11:00:00'), None, None, 199.5, -3, -78, 5070, -1.0, 1484, 9)
# Not Inserted:
# (Timestamp('2017-09-19 15:00:00'), Timestamp('2017-09-19 15:00:00'), None, Timestamp('2017-09-18 09:04:00'), Timestamp('2017-09-20 09:00:00'), None, None, 299.9, -1, -29, 5071, -1.0, 1529, 9)
# Not Inserted:
# (Timestamp('2017-08-01 12:00:00'), Timestamp('2017-08-01 14:00:00'), None, Timestamp('2017-08-01 12:02:00'), Timestamp('2017-08-02 00:00:00'), None, None, 250.6, 0, 0, 5072, -1.0, 1476, 9)
# Not Inserted:
# (Timestamp('2017-06-11 17:00:00'), Timestamp('2017-06-11 17:00:00'), None, Timestamp('2017-06-08 11:01:00'), Timestamp('2017-06-12 12:00:00'), None, None, 430.4, -3, -77, 5073, -1.0, 742, 9)
# Not Inserted:
# (Timestamp('2017-10-27 16:00:00'), Timestamp('2017-10-27 16:00:00'), None, Timestamp('2017-10-24 17:39:00'), Timestamp('2017-10-30 16:00:00'), None, None, 1787.6, -2, -70, 5074, -1.0, 230, 9)
# Not Inserted:
# (Timestamp('2017-05-03 10:00:00'), Timestamp('2017-05-03 18:00:00'), None, Timestamp('2017-05-01 16:39:00'), Timestamp('2017-05-03 17:00:00'), None, None, 384.3, -1, -41, 5075, -1.0, 1104, 9)
# Not Inserted:
# (Timestamp('2017-10-04 08:00:00'), Timestamp('2017-10-04 12:00:00'), None, Timestamp('2017-10-02 16:11:00'), Timestamp('2017-10-05 23:00:00'), None, None, 212.5, -1, -39, 5076, -1.0, 912, 9)
# Not Inserted:
# (Timestamp('2017-05-24 23:00:00'), Timestamp('2017-05-24 23:00:00'), None, Timestamp('2017-05-24 17:42:00'), Timestamp('2017-05-26 17:00:00'), None, None, 99.5, 0, -5, 5077, -1.0, 357, 9)
# Not Inserted:
# (Timestamp('2017-06-02 18:00:00'), Timestamp('2017-06-02 18:00:00'), None, Timestamp('2017-05-31 16:43:00'), Timestamp('2017-06-05 10:00:00'), None, None, 381.1, -2, -49, 5078, -1.0, 987, 9)
# Not Inserted:
# (Timestamp('2017-06-07 01:00:00'), Timestamp('2017-06-07 01:00:00'), None, Timestamp('2017-05-31 17:56:00'), Timestamp('2017-06-07 15:00:00'), None, None, 354.3, -6, -151, 5079, -1.0, 1501, 9)
# Not Inserted:
# (Timestamp('2017-09-11 12:00:00'), Timestamp('2017-09-11 14:00:00'), None, Timestamp('2017-09-08 19:24:00'), Timestamp('2017-09-12 02:00:00'), None, None, 293.2, -2, -64, 5080, -1.0, 974, 9)
# Not Inserted:
# (Timestamp('2017-07-29 19:00:00'), Timestamp('2017-07-29 19:00:00'), None, Timestamp('2017-07-31 09:29:00'), Timestamp('2017-07-31 11:00:00'), None, None, 794.6, 1, 38, 5081, -1.0, 1530, 9)
# Not Inserted:
# (Timestamp('2017-05-16 09:00:00'), Timestamp('2017-05-16 17:00:00'), None, Timestamp('2017-05-12 16:30:00'), Timestamp('2017-05-18 17:00:00'), None, None, 1168.2, -3, -88, 5082, -1.0, 277, 9)
# Not Inserted:
# (Timestamp('2017-05-12 10:00:00'), Timestamp('2017-05-12 18:00:00'), None, Timestamp('2017-05-10 13:34:00'), Timestamp('2017-05-12 18:00:00'), None, None, 332.8, -1, -44, 5083, -1.0, 638, 9)
# Not Inserted:
# (Timestamp('2018-01-02 12:00:00'), Timestamp('2018-01-02 14:00:00'), None, Timestamp('2017-12-29 13:02:00'), Timestamp('2018-01-03 04:00:00'), None, None, 328.8, -3, -94, 5084, -1.0, 552, 9)
# Not Inserted:
# (Timestamp('2017-04-17 17:00:00'), Timestamp('2017-04-17 17:00:00'), None, Timestamp('2017-04-14 09:57:00'), Timestamp('2017-04-18 11:00:00'), None, None, 199.5, -3, -79, 5085, -1.0, 1484, 9)
# Not Inserted:
# (Timestamp('2017-12-19 23:00:00'), Timestamp('2017-12-20 01:00:00'), None, Timestamp('2017-12-18 18:40:00'), Timestamp('2017-12-20 18:00:00'), None, None, 391.2, -1, -28, 5086, -1.0, 571, 9)
# Not Inserted:
# (Timestamp('2017-07-31 09:00:00'), Timestamp('2017-07-31 11:00:00'), None, Timestamp('2017-07-24 14:24:00'), Timestamp('2017-07-31 18:00:00'), None, None, 173.3, -6, -162, 5087, -1.0, 503, 9)
# Not Inserted:
# (Timestamp('2017-04-11 10:00:00'), Timestamp('2017-04-11 18:00:00'), None, Timestamp('2017-04-07 16:48:00'), Timestamp('2017-04-12 18:00:00'), None, None, 625.2, -3, -89, 5088, -1.0, 657, 9)
# Not Inserted:
# (Timestamp('2017-08-10 13:30:00'), Timestamp('2017-08-10 13:30:00'), None, Timestamp('2017-08-10 15:46:00'), Timestamp('2017-08-11 09:00:00'), None, None, 348.2, 0, 2, 5089, -1.0, 1531, 9)
# Not Inserted:
# (Timestamp('2017-09-11 22:00:00'), Timestamp('2017-09-12 00:00:00'), None, Timestamp('2017-09-11 08:58:00'), Timestamp('2017-09-12 15:00:00'), None, None, 357.5, 0, -13, 5090, -1.0, 1481, 9)
# Not Inserted:
# (Timestamp('2017-10-24 15:00:00'), Timestamp('2017-10-24 15:00:00'), None, Timestamp('2017-10-23 16:35:00'), Timestamp('2017-10-25 09:00:00'), None, None, 339.5, 0, -22, 5091, -1.0, 776, 9)
# Not Inserted:
# (Timestamp('2017-09-11 22:00:00'), Timestamp('2017-09-12 00:00:00'), None, Timestamp('2017-09-10 19:29:00'), Timestamp('2017-09-12 16:00:00'), None, None, 377.1, -1, -26, 5092, -1.0, 1532, 9)
# Not Inserted:
# (Timestamp('2017-04-19 02:00:00'), Timestamp('2017-04-19 02:00:00'), None, Timestamp('2017-04-18 11:52:00'), Timestamp('2017-04-19 17:00:00'), None, None, 387.7, 0, -14, 5093, -1.0, 1251, 9)
# Not Inserted:
# (Timestamp('2017-05-12 10:00:00'), Timestamp('2017-05-12 18:00:00'), None, Timestamp('2017-05-10 13:35:00'), Timestamp('2017-05-12 18:00:00'), None, None, 438.4, -1, -44, 5094, -1.0, 507, 9)
# Not Inserted:
# (Timestamp('2017-12-05 12:00:00'), Timestamp('2017-12-05 12:00:00'), None, Timestamp('2017-12-04 17:54:00'), Timestamp('2017-12-06 07:45:00'), None, None, 555.6, 0, -18, 5095, -1.0, 513, 9)
# Not Inserted:
# (Timestamp('2017-05-04 09:00:00'), Timestamp('2017-05-04 17:00:00'), None, Timestamp('2017-05-02 13:50:00'), Timestamp('2017-05-04 17:00:00'), None, None, 105.2, -1, -43, 5096, -1.0, 1441, 9)
# Not Inserted:
# (Timestamp('2017-06-30 10:00:00'), Timestamp('2017-06-30 18:00:00'), None, Timestamp('2017-06-27 17:19:00'), Timestamp('2017-07-01 18:00:00'), None, None, 749.8, -2, -64, 5098, -1.0, 269, 9)
# Not Inserted:
# (Timestamp('2017-04-17 16:00:00'), Timestamp('2017-04-17 16:00:00'), None, Timestamp('2017-04-14 09:55:00'), Timestamp('2017-04-18 11:00:00'), None, None, 199.5, -3, -78, 5099, -1.0, 1484, 9)
# Not Inserted:
# (Timestamp('2017-12-20 11:00:00'), Timestamp('2017-12-20 13:00:00'), None, Timestamp('2017-12-19 11:08:00'), Timestamp('2017-12-21 03:00:00'), None, None, 339.5, 0, -23, 5100, -1.0, 776, 9)
# Not Inserted:
# (Timestamp('2017-06-08 00:00:00'), Timestamp('2017-06-08 00:00:00'), None, Timestamp('2017-06-07 11:48:00'), Timestamp('2017-06-08 12:00:00'), None, None, 266.6, 0, -12, 5101, -1.0, 724, 9)
# Not Inserted:
# (Timestamp('2017-04-20 06:00:00'), Timestamp('2017-04-20 06:00:00'), None, Timestamp('2017-04-17 17:28:00'), Timestamp('2017-04-21 09:15:00'), None, None, 603.5, -2, -60, 5102, -1.0, 1533, 9)
# Not Inserted:
# (Timestamp('2017-05-26 09:00:00'), Timestamp('2017-05-26 17:00:00'), None, Timestamp('2017-05-24 17:43:00'), Timestamp('2017-05-26 17:00:00'), None, None, 84.4, -1, -39, 5103, -1.0, 512, 9)
# Not Inserted:
# (Timestamp('2017-09-29 14:00:00'), Timestamp('2017-09-29 14:00:00'), None, Timestamp('2017-09-28 11:54:00'), Timestamp('2017-10-04 21:00:00'), None, None, 2899.0, -1, -26, 5104, -1.0, 1534, 9)
# Not Inserted:
# (Timestamp('2017-09-25 17:00:00'), Timestamp('2017-09-25 17:00:00'), None, Timestamp('2017-09-22 15:30:00'), Timestamp('2017-09-26 11:30:00'), None, None, 205.8, -3, -73, 5105, -1.0, 1535, 9)
# Not Inserted:
# (Timestamp('2017-08-31 14:00:00'), Timestamp('2017-08-31 16:00:00'), None, Timestamp('2017-08-31 13:03:00'), Timestamp('2017-09-01 06:00:00'), None, None, 337.4, 0, 0, 5106, -1.0, 442, 9)
# Not Inserted:
# (Timestamp('2017-05-02 23:00:00'), Timestamp('2017-05-02 23:00:00'), None, Timestamp('2017-05-01 14:03:00'), Timestamp('2017-05-03 13:00:00'), None, None, 222.1, -1, -32, 5107, -1.0, 1536, 9)
# Not Inserted:
# (Timestamp('2017-05-01 06:00:00'), Timestamp('2017-05-01 06:00:00'), None, Timestamp('2017-05-01 12:26:00'), Timestamp('2017-05-02 17:00:00'), None, None, 121.4, 0, 6, 5108, -1.0, 1537, 9)
# Not Inserted:
# (Timestamp('2017-08-03 09:00:00'), Timestamp('2017-08-03 09:00:00'), None, Timestamp('2017-08-01 17:46:00'), Timestamp('2017-08-04 17:00:00'), None, None, 699.6, -1, -39, 5109, -1.0, 1538, 9)
# Not Inserted:
# (Timestamp('2017-05-17 16:00:00'), Timestamp('2017-05-17 16:00:00'), None, Timestamp('2017-05-16 17:26:00'), Timestamp('2017-05-18 13:30:00'), None, None, 86.1, 0, -22, 5110, -1.0, 512, 9)
# Not Inserted:
# (Timestamp('2017-11-03 16:00:00'), Timestamp('2017-11-03 16:00:00'), None, Timestamp('2017-10-31 18:01:00'), Timestamp('2017-11-06 14:00:00'), None, None, 889.1, -2, -69, 5111, -1.0, 1539, 9)
# Not Inserted:
# (Timestamp('2017-06-23 09:00:00'), Timestamp('2017-06-23 17:00:00'), None, Timestamp('2017-06-23 08:09:00'), Timestamp('2017-06-25 00:00:00'), None, None, 278.5, 0, 0, 5112, -1.0, 1540, 9)
# Not Inserted:
# (Timestamp('2017-09-08 12:00:00'), Timestamp('2017-09-08 14:00:00'), None, Timestamp('2017-09-07 16:56:00'), Timestamp('2017-09-09 01:00:00'), None, None, 252.6, 0, -19, 5113, -1.0, 484, 9)
# Not Inserted:
# (Timestamp('2017-12-05 15:00:00'), Timestamp('2017-12-05 15:00:00'), None, Timestamp('2017-12-04 14:40:00'), Timestamp('2017-12-07 23:00:00'), None, None, 1409.6, -1, -24, 5114, -1.0, 1480, 9)
# Not Inserted:
# (Timestamp('2017-05-03 12:00:00'), Timestamp('2017-05-03 12:00:00'), None, Timestamp('2017-05-02 15:40:00'), Timestamp('2017-05-05 15:00:00'), None, None, 1769.0, 0, -20, 5115, -1.0, 1508, 9)
# Not Inserted:
# (Timestamp('2017-08-25 19:00:00'), Timestamp('2017-08-25 19:00:00'), None, Timestamp('2017-08-23 16:48:00'), Timestamp('2017-08-28 17:30:00'), None, None, 629.4, -2, -50, 5116, -1.0, 346, 9)
# Not Inserted:
# (Timestamp('2017-03-29 09:00:00'), Timestamp('2017-03-29 17:00:00'), None, Timestamp('2017-03-28 09:14:00'), Timestamp('2017-03-30 14:00:00'), None, None, 666.3, 0, -23, 5117, -1.0, 1541, 9)
# Not Inserted:
# (Timestamp('2017-09-12 23:00:00'), Timestamp('2017-09-13 01:00:00'), None, Timestamp('2017-09-11 16:33:00'), Timestamp('2017-09-13 13:00:00'), None, None, 285.2, -1, -30, 5119, -1.0, 648, 9)
# Not Inserted:
# (Timestamp('2017-04-25 02:00:00'), Timestamp('2017-04-25 02:00:00'), None, Timestamp('2017-04-24 09:49:00'), Timestamp('2017-04-25 13:30:00'), None, None, 188.8, 0, -16, 5120, -1.0, 1528, 9)
# Not Inserted:
# (Timestamp('2017-08-02 11:00:00'), Timestamp('2017-08-02 15:00:00'), None, Timestamp('2017-08-02 12:10:00'), Timestamp('2017-08-02 11:00:00'), None, None, 300.0, 0, 1, 5121, -1.0, 468, 9)
# Not Inserted:
# (Timestamp('2017-06-28 18:00:00'), Timestamp('2017-06-28 18:00:00'), None, Timestamp('2017-06-28 18:26:00'), Timestamp('2017-06-30 14:00:00'), None, None, 714.9, 0, 0, 5122, -1.0, 287, 9)

# %%
connection.commit()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-23-867cb5486458> in <module>
# ----> 1 connection.commit()
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in commit(self)
#     467         in the specification.
#     468         """
# --> 469         self._execute_command(COMMAND.COM_QUERY, "COMMIT")
#     470         self._read_ok_packet()
#     471
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _execute_command(self, command, sql)
#     791         """
#     792         if not self._sock:
# --> 793             raise err.InterfaceError(0, "")
#     794
#     795         # If the last query was unbuffered, make sure it finishes before
#
# InterfaceError: (0, '')

# %% [markdown]
# ## Closing Database Connection

# %%
connection.close()

# %%
from sqlalchemy import create_engine

ssl_args = {'sslrootcert':'server-ca.pem',             
            'sslcert':'client-cert.pem',             
            'sslkey':'client-key.pem'}
ssl_args ={'ssl': {'ca': 'server-ca.pem',
           'key':'client-key.pem',
           'cert':'client-cert.pem',
           'check_hostname':False
        }}
engine = create_engine("mysql+pymysql://loadsmart_user:loadsmart_user@loadsmart_dw/",
                        connect_args=ssl_args)

# %%
with engine.begin() as conn:
    FactTransport.to_sql('FactTransport', con=conn, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\socket.py in create_connection(address, timeout, source_address)
#     786     err = None
# --> 787     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     788         af, socktype, proto, canonname, sa = res
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3112         try:
# -> 3113             return fn()
#    3114         except dialect.dbapi.Error as e:
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     197         try:
# --> 198             raise exception
#     199         finally:
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     197         try:
# --> 198             raise exception
#     199         finally:
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     547         # inherits the docstring from interfaces.Dialect.connect
# --> 548         return self.dbapi.connect(*cargs, **cparams)
#     549
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     352         else:
# --> 353             self.connect()
#     354
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#
# OperationalError: (2003, "Can't connect to MySQL server on 'loadsmart_dw' ([Errno 11001] getaddrinfo failed)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-34-9d059b821a12> in <module>
# ----> 1 with engine.begin() as conn:
#       2     FactTransport.to_sql('FactTransport', con=conn, if_exists='append')
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in begin(self, close_with_result)
#    2893             conn = self.connect()
#    2894         else:
# -> 2895             conn = self.connect(close_with_result=close_with_result)
#    2896         try:
#    2897             trans = conn.begin()
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3065         """
#    3066
# -> 3067         return self._connection_cls(self, close_with_result=close_with_result)
#    3068
#    3069     @util.deprecated(
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      89                 connection
#      90                 if connection is not None
# ---> 91                 else engine.raw_connection()
#      92             )
#      93
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3144
#    3145         """
# -> 3146         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3147
#    3148
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3114         except dialect.dbapi.Error as e:
#    3115             if connection is None:
# -> 3116                 Connection._handle_dbapi_exception_noconnection(
#    3117                     e, dialect, self
#    3118                 )
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2001             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2002         elif should_wrap:
# -> 2003             util.raise_(
#    2004                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2005             )
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     196
#     197         try:
# --> 198             raise exception
#     199         finally:
#     200             # credit to
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3111         dialect = self.dialect
#    3112         try:
# -> 3113             return fn()
#    3114         except dialect.dbapi.Error as e:
#    3115             if connection is None:
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     299
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#     303     def _return_conn(self, record):
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     753     def _checkout(cls, pool, threadconns=None, fairy=None):
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#     757             fairy._pool = pool
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     417     @classmethod
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#     421             dbapi_connection = rec.get_connection()
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     143             except:
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#     147             return self._do_get()
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     196
#     197         try:
# --> 198             raise exception
#     199         finally:
#     200             # credit to
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     140         if self._inc_overflow():
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#     144                 with util.safe_reraise():
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     245         """Called by subclasses to create a new ConnectionRecord."""
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#     249     def _invalidate(self, connection, exception=None, _checkin=True):
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     360         self.__pool = pool
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#     364
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     603         except Exception as e:
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#     607             if first_connect_check:
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     196
#     197         try:
# --> 198             raise exception
#     199         finally:
#     200             # credit to
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     597         try:
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#     601             self.connection = connection
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     546     def connect(self, *cargs, **cparams):
#     547         # inherits the docstring from interfaces.Dialect.connect
# --> 548         return self.dbapi.connect(*cargs, **cparams)
#     549
#     550     def create_connect_args(self, url):
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     662                 if DEBUG:
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#     666             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on 'loadsmart_dw' ([Errno 11001] getaddrinfo failed)")
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
FactTransport.to_sql('FactTransport', con=connection, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1696         try:
# -> 1697             cur.execute(*args, **kwargs)
#    1698             return cur
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     145
# --> 146         query = self.mogrify(query, args)
#     147
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in mogrify(self, query, args)
#     124         if args is not None:
# --> 125             query = query % self._escape_args(args, conn)
#     126
#
# TypeError: not all arguments converted during string formatting
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-38-816a1c144b62> in <module>
# ----> 1 FactTransport.to_sql('FactTransport', con=connection, if_exists='append')
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     588         )
#     589
# --> 590     pandas_sql.to_sql(
#     591         frame,
#     592         name,
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1841             dtype=dtype,
#    1842         )
# -> 1843         table.create()
#    1844         table.insert(chunksize, method)
#    1845
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in create(self)
#     720
#     721     def create(self):
# --> 722         if self.exists():
#     723             if self.if_exists == "fail":
#     724                 raise ValueError(f"Table '{self.name}' already exists.")
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in exists(self)
#     707
#     708     def exists(self):
# --> 709         return self.pd_sql.has_table(self.name, self.schema)
#     710
#     711     def sql_schema(self):
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1852         query = f"SELECT name FROM sqlite_master WHERE type='table' AND name={wld};"
#    1853
# -> 1854         return len(self.execute(query, [name]).fetchall()) > 0
#    1855
#    1856     def get_table(self, table_name, schema=None):
#
# c:\users\cesar\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1707
#    1708             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1709             raise ex from exc
#    1710
#    1711     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT name FROM sqlite_master WHERE type='table' AND name=?;': not all arguments converted during string formatting
